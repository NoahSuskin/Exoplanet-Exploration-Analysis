# %%
from numpy.random import seed
seed(1)
import pandas as pd
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# loading data into a dataframe

file_path = '../Resources/exoplanet_data.csv'

df = pd.read_csv(file_path)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Setting features and target
target = df['koi_disposition']
selected_features = df.drop(['koi_disposition'], axis=1)

# Selected Feature Names
feature_names = selected_features.columns.tolist()

# looking at the shape of the variables
print(target.shape, selected_features.shape)
# Out:
# (6991,) (6991, 40)

# %%
# Splitting the data into a training set and testing set and scaling

X_train, X_test, y_train, y_test = train_test_split(selected_features, target, random_state=42)

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Encoding the target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Converting the encoded target variable into a catagorical form
y_train_catagorical = to_categorical(encoded_y_train)
y_test_catagorical = to_categorical(encoded_y_test)

# %%
# Creating the deep model

deep_model = Sequential()
deep_model.add(Dense(units=10, activation='relu', input_dim=40))
deep_model.add(Dense(units=10, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model

deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.9578 - accuracy: 0.4921
# Epoch 2/100
# 164/164 - 0s - loss: 0.5860 - accuracy: 0.7461
# Epoch 3/100
# 164/164 - 0s - loss: 0.4308 - accuracy: 0.7919
# Epoch 4/100
# 164/164 - 0s - loss: 0.3924 - accuracy: 0.8068
# Epoch 5/100
# 164/164 - 0s - loss: 0.3800 - accuracy: 0.8085
# Epoch 6/100
# 164/164 - 0s - loss: 0.3731 - accuracy: 0.8062
# Epoch 7/100
# 164/164 - 0s - loss: 0.3649 - accuracy: 0.8201
# Epoch 8/100
# 164/164 - 0s - loss: 0.3603 - accuracy: 0.8161
# Epoch 9/100
# 164/164 - 0s - loss: 0.3549 - accuracy: 0.8236
# Epoch 10/100
# 164/164 - 0s - loss: 0.3502 - accuracy: 0.8245
# Epoch 11/100
# 164/164 - 0s - loss: 0.3450 - accuracy: 0.8259
# Epoch 12/100
# 164/164 - 0s - loss: 0.3427 - accuracy: 0.8310
# Epoch 13/100
# 164/164 - 0s - loss: 0.3370 - accuracy: 0.8346
# Epoch 14/100
# 164/164 - 0s - loss: 0.3349 - accuracy: 0.8362
# Epoch 15/100
# 164/164 - 0s - loss: 0.3327 - accuracy: 0.8352
# Epoch 16/100
# 164/164 - 0s - loss: 0.3319 - accuracy: 0.8379
# Epoch 17/100
# 164/164 - 0s - loss: 0.3245 - accuracy: 0.8442
# Epoch 18/100
# 164/164 - 0s - loss: 0.3244 - accuracy: 0.8444
# Epoch 19/100
# 164/164 - 0s - loss: 0.3229 - accuracy: 0.8419
# Epoch 20/100
# 164/164 - 0s - loss: 0.3194 - accuracy: 0.8510
# Epoch 21/100
# 164/164 - 0s - loss: 0.3165 - accuracy: 0.8533
# Epoch 22/100
# 164/164 - 0s - loss: 0.3138 - accuracy: 0.8493
# Epoch 23/100
# 164/164 - 0s - loss: 0.3115 - accuracy: 0.8535
# Epoch 24/100
# 164/164 - 0s - loss: 0.3108 - accuracy: 0.8562
# Epoch 25/100
# 164/164 - 0s - loss: 0.3102 - accuracy: 0.8550
# Epoch 26/100
# 164/164 - 0s - loss: 0.3088 - accuracy: 0.8560
# Epoch 27/100
# 164/164 - 0s - loss: 0.3056 - accuracy: 0.8629
# Epoch 28/100
# 164/164 - 0s - loss: 0.3034 - accuracy: 0.8615
# Epoch 29/100
# 164/164 - 0s - loss: 0.3033 - accuracy: 0.8642
# Epoch 30/100
# 164/164 - 0s - loss: 0.3023 - accuracy: 0.8629
# Epoch 31/100
# 164/164 - 0s - loss: 0.3024 - accuracy: 0.8596
# Epoch 32/100
# 164/164 - 0s - loss: 0.3016 - accuracy: 0.8631
# Epoch 33/100
# 164/164 - 0s - loss: 0.2973 - accuracy: 0.8673
# Epoch 34/100
# 164/164 - 0s - loss: 0.2961 - accuracy: 0.8650
# Epoch 35/100
# 164/164 - 0s - loss: 0.2951 - accuracy: 0.8680
# Epoch 36/100
# 164/164 - 0s - loss: 0.2950 - accuracy: 0.8686
# Epoch 37/100
# 164/164 - 0s - loss: 0.2955 - accuracy: 0.8669
# Epoch 38/100
# 164/164 - 0s - loss: 0.2938 - accuracy: 0.8705
# Epoch 39/100
# 164/164 - 0s - loss: 0.2932 - accuracy: 0.8714
# Epoch 40/100
# 164/164 - 0s - loss: 0.2924 - accuracy: 0.8726
# Epoch 41/100
# 164/164 - 0s - loss: 0.2918 - accuracy: 0.8707
# Epoch 42/100
# 164/164 - 0s - loss: 0.2912 - accuracy: 0.8709
# Epoch 43/100
# 164/164 - 0s - loss: 0.2901 - accuracy: 0.8693
# Epoch 44/100
# 164/164 - 0s - loss: 0.2899 - accuracy: 0.8739
# Epoch 45/100
# 164/164 - 0s - loss: 0.2905 - accuracy: 0.8722
# Epoch 46/100
# 164/164 - 0s - loss: 0.2859 - accuracy: 0.8732
# Epoch 47/100
# 164/164 - 1s - loss: 0.2861 - accuracy: 0.8787
# Epoch 48/100
# 164/164 - 1s - loss: 0.2858 - accuracy: 0.8714
# Epoch 49/100
# 164/164 - 1s - loss: 0.2856 - accuracy: 0.8758
# Epoch 50/100
# 164/164 - 0s - loss: 0.2832 - accuracy: 0.8739
# Epoch 51/100
# 164/164 - 0s - loss: 0.2888 - accuracy: 0.8732
# Epoch 52/100
# 164/164 - 0s - loss: 0.2847 - accuracy: 0.8755
# Epoch 53/100
# 164/164 - 0s - loss: 0.2841 - accuracy: 0.8735
# Epoch 54/100
# 164/164 - 0s - loss: 0.2841 - accuracy: 0.8747
# Epoch 55/100
# 164/164 - 0s - loss: 0.2824 - accuracy: 0.8758
# Epoch 56/100
# 164/164 - 0s - loss: 0.2835 - accuracy: 0.8772
# Epoch 57/100
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8795
# Epoch 58/100
# 164/164 - 0s - loss: 0.2829 - accuracy: 0.8781
# Epoch 59/100
# 164/164 - 0s - loss: 0.2818 - accuracy: 0.8764
# Epoch 60/100
# 164/164 - 0s - loss: 0.2817 - accuracy: 0.8787
# Epoch 61/100
# 164/164 - 0s - loss: 0.2822 - accuracy: 0.8753
# Epoch 62/100
# 164/164 - 1s - loss: 0.2821 - accuracy: 0.8777
# Epoch 63/100
# 164/164 - 1s - loss: 0.2794 - accuracy: 0.8795
# Epoch 64/100
# 164/164 - 0s - loss: 0.2801 - accuracy: 0.8758
# Epoch 65/100
# 164/164 - 1s - loss: 0.2799 - accuracy: 0.8787
# Epoch 66/100
# 164/164 - 1s - loss: 0.2795 - accuracy: 0.8795
# Epoch 67/100
# 164/164 - 1s - loss: 0.2781 - accuracy: 0.8800
# Epoch 68/100
# 164/164 - 1s - loss: 0.2778 - accuracy: 0.8781
# Epoch 69/100
# 164/164 - 0s - loss: 0.2793 - accuracy: 0.8793
# Epoch 70/100
# 164/164 - 0s - loss: 0.2819 - accuracy: 0.8814
# Epoch 71/100
# 164/164 - 0s - loss: 0.2775 - accuracy: 0.8833
# Epoch 72/100
# 164/164 - 0s - loss: 0.2768 - accuracy: 0.8821
# Epoch 73/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8835
# Epoch 74/100
# 164/164 - 0s - loss: 0.2782 - accuracy: 0.8802
# Epoch 75/100
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8821
# Epoch 76/100
# 164/164 - 0s - loss: 0.2781 - accuracy: 0.8793
# Epoch 77/100
# 164/164 - 0s - loss: 0.2762 - accuracy: 0.8861
# Epoch 78/100
# 164/164 - 0s - loss: 0.2762 - accuracy: 0.8816
# Epoch 79/100
# 164/164 - 0s - loss: 0.2750 - accuracy: 0.8816
# Epoch 80/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8814
# Epoch 81/100
# 164/164 - 0s - loss: 0.2758 - accuracy: 0.8829
# Epoch 82/100
# 164/164 - 0s - loss: 0.2746 - accuracy: 0.8833
# Epoch 83/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8833
# Epoch 84/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8852
# Epoch 85/100
# 164/164 - 0s - loss: 0.2726 - accuracy: 0.8838
# Epoch 86/100
# 164/164 - 0s - loss: 0.2722 - accuracy: 0.8823
# Epoch 87/100
# 164/164 - 0s - loss: 0.2710 - accuracy: 0.8844
# Epoch 88/100
# 164/164 - 0s - loss: 0.2711 - accuracy: 0.8802
# Epoch 89/100
# 164/164 - 0s - loss: 0.2712 - accuracy: 0.8814
# Epoch 90/100
# 164/164 - 0s - loss: 0.2720 - accuracy: 0.8808
# Epoch 91/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8825
# Epoch 92/100
# 164/164 - 0s - loss: 0.2715 - accuracy: 0.8867
# Epoch 93/100
# 164/164 - 0s - loss: 0.2732 - accuracy: 0.8829
# Epoch 94/100
# 164/164 - 0s - loss: 0.2712 - accuracy: 0.8852
# Epoch 95/100
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8831
# Epoch 96/100
# 164/164 - 0s - loss: 0.2706 - accuracy: 0.8859
# Epoch 97/100
# 164/164 - 0s - loss: 0.2697 - accuracy: 0.8846
# Epoch 98/100
# 164/164 - 0s - loss: 0.2665 - accuracy: 0.8907
# Epoch 99/100
# 164/164 - 0s - loss: 0.2739 - accuracy: 0.8810
# Epoch 100/100
# 164/164 - 0s - loss: 0.2682 - accuracy: 0.8882

# %%
# scoring the model

deep_model_loss, deep_model_accuracy = deep_model.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2913 - accuracy: 0.8781
# Normal Neural Network - Loss: 0.2912806570529938, Accuracy: 0.8781464695930481

# %%
# Creating a model with more neural layers

deep_model2 = Sequential()
deep_model2.add(Dense(units=10, activation='relu', input_dim=40))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model with more layers

deep_model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model2.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.8425 - accuracy: 0.5745
# Epoch 2/100
# 164/164 - 0s - loss: 0.4477 - accuracy: 0.7545
# Epoch 3/100
# 164/164 - 0s - loss: 0.3896 - accuracy: 0.7877
# Epoch 4/100
# 164/164 - 0s - loss: 0.3801 - accuracy: 0.7992
# Epoch 5/100
# 164/164 - 0s - loss: 0.3718 - accuracy: 0.8072
# Epoch 6/100
# 164/164 - 0s - loss: 0.3709 - accuracy: 0.8085
# Epoch 7/100
# 164/164 - 0s - loss: 0.3628 - accuracy: 0.8182
# Epoch 8/100
# 164/164 - 0s - loss: 0.3612 - accuracy: 0.8127
# Epoch 9/100
# 164/164 - 0s - loss: 0.3581 - accuracy: 0.8129
# Epoch 10/100
# 164/164 - 0s - loss: 0.3548 - accuracy: 0.8213
# Epoch 11/100
# 164/164 - 0s - loss: 0.3512 - accuracy: 0.8285
# Epoch 12/100
# 164/164 - 0s - loss: 0.3500 - accuracy: 0.8264
# Epoch 13/100
# 164/164 - 0s - loss: 0.3514 - accuracy: 0.8236
# Epoch 14/100
# 164/164 - 0s - loss: 0.3470 - accuracy: 0.8280
# Epoch 15/100
# 164/164 - 0s - loss: 0.3461 - accuracy: 0.8262
# Epoch 16/100
# 164/164 - 0s - loss: 0.3436 - accuracy: 0.8322
# Epoch 17/100
# 164/164 - 0s - loss: 0.3444 - accuracy: 0.8331
# Epoch 18/100
# 164/164 - 0s - loss: 0.3396 - accuracy: 0.8312
# Epoch 19/100
# 164/164 - 1s - loss: 0.3397 - accuracy: 0.8285
# Epoch 20/100
# 164/164 - 0s - loss: 0.3428 - accuracy: 0.8285
# Epoch 21/100
# 164/164 - 1s - loss: 0.3359 - accuracy: 0.8369
# Epoch 22/100
# 164/164 - 0s - loss: 0.3390 - accuracy: 0.8293
# Epoch 23/100
# 164/164 - 0s - loss: 0.3331 - accuracy: 0.8364
# Epoch 24/100
# 164/164 - 0s - loss: 0.3333 - accuracy: 0.8367
# Epoch 25/100
# 164/164 - 0s - loss: 0.3348 - accuracy: 0.8327
# Epoch 26/100
# 164/164 - 0s - loss: 0.3337 - accuracy: 0.8381
# Epoch 27/100
# 164/164 - 0s - loss: 0.3326 - accuracy: 0.8411
# Epoch 28/100
# 164/164 - 0s - loss: 0.3316 - accuracy: 0.8381
# Epoch 29/100
# 164/164 - 0s - loss: 0.3317 - accuracy: 0.8369
# Epoch 30/100
# 164/164 - 0s - loss: 0.3328 - accuracy: 0.8402
# Epoch 31/100
# 164/164 - 0s - loss: 0.3350 - accuracy: 0.8346
# Epoch 32/100
# 164/164 - 0s - loss: 0.3296 - accuracy: 0.8385
# Epoch 33/100
# 164/164 - 0s - loss: 0.3279 - accuracy: 0.8468
# Epoch 34/100
# 164/164 - 0s - loss: 0.3287 - accuracy: 0.8432
# Epoch 35/100
# 164/164 - 0s - loss: 0.3286 - accuracy: 0.8421
# Epoch 36/100
# 164/164 - 0s - loss: 0.3253 - accuracy: 0.8453
# Epoch 37/100
# 164/164 - 0s - loss: 0.3291 - accuracy: 0.8447
# Epoch 38/100
# 164/164 - 0s - loss: 0.3286 - accuracy: 0.8415
# Epoch 39/100
# 164/164 - 0s - loss: 0.3291 - accuracy: 0.8434
# Epoch 40/100
# 164/164 - 0s - loss: 0.3301 - accuracy: 0.8438
# Epoch 41/100
# 164/164 - 0s - loss: 0.3234 - accuracy: 0.8488
# Epoch 42/100
# 164/164 - 0s - loss: 0.3239 - accuracy: 0.8493
# Epoch 43/100
# 164/164 - 0s - loss: 0.3270 - accuracy: 0.8447
# Epoch 44/100
# 164/164 - 0s - loss: 0.3205 - accuracy: 0.8510
# Epoch 45/100
# 164/164 - 0s - loss: 0.3164 - accuracy: 0.8552
# Epoch 46/100
# 164/164 - 0s - loss: 0.3147 - accuracy: 0.8568
# Epoch 47/100
# 164/164 - 0s - loss: 0.3168 - accuracy: 0.8570
# Epoch 48/100
# 164/164 - 0s - loss: 0.3152 - accuracy: 0.8516
# Epoch 49/100
# 164/164 - 0s - loss: 0.3234 - accuracy: 0.8510
# Epoch 50/100
# 164/164 - 0s - loss: 0.3161 - accuracy: 0.8541
# Epoch 51/100
# 164/164 - 0s - loss: 0.3134 - accuracy: 0.8581
# Epoch 52/100
# 164/164 - 0s - loss: 0.3119 - accuracy: 0.8552
# Epoch 53/100
# 164/164 - 0s - loss: 0.3073 - accuracy: 0.8610
# Epoch 54/100
# 164/164 - 0s - loss: 0.3101 - accuracy: 0.8581
# Epoch 55/100
# 164/164 - 0s - loss: 0.3061 - accuracy: 0.8602
# Epoch 56/100
# 164/164 - 0s - loss: 0.3064 - accuracy: 0.8623
# Epoch 57/100
# 164/164 - 0s - loss: 0.3114 - accuracy: 0.8577
# Epoch 58/100
# 164/164 - 0s - loss: 0.3055 - accuracy: 0.8621
# Epoch 59/100
# 164/164 - 0s - loss: 0.3026 - accuracy: 0.8693
# Epoch 60/100
# 164/164 - 0s - loss: 0.3046 - accuracy: 0.8627
# Epoch 61/100
# 164/164 - 0s - loss: 0.2992 - accuracy: 0.8697
# Epoch 62/100
# 164/164 - 1s - loss: 0.2962 - accuracy: 0.8692
# Epoch 63/100
# 164/164 - 1s - loss: 0.2978 - accuracy: 0.8671
# Epoch 64/100
# 164/164 - 0s - loss: 0.2925 - accuracy: 0.8718
# Epoch 65/100
# 164/164 - 0s - loss: 0.2951 - accuracy: 0.8692
# Epoch 66/100
# 164/164 - 0s - loss: 0.2921 - accuracy: 0.8728
# Epoch 67/100
# 164/164 - 0s - loss: 0.3021 - accuracy: 0.8678
# Epoch 68/100
# 164/164 - 0s - loss: 0.2900 - accuracy: 0.8703
# Epoch 69/100
# 164/164 - 0s - loss: 0.2891 - accuracy: 0.8703
# Epoch 70/100
# 164/164 - 0s - loss: 0.2892 - accuracy: 0.8768
# Epoch 71/100
# 164/164 - 0s - loss: 0.2884 - accuracy: 0.8743
# Epoch 72/100
# 164/164 - 0s - loss: 0.2876 - accuracy: 0.8760
# Epoch 73/100
# 164/164 - 0s - loss: 0.2915 - accuracy: 0.8707
# Epoch 74/100
# 164/164 - 0s - loss: 0.2878 - accuracy: 0.8758
# Epoch 75/100
# 164/164 - 0s - loss: 0.2885 - accuracy: 0.8735
# Epoch 76/100
# 164/164 - 0s - loss: 0.2796 - accuracy: 0.8821
# Epoch 77/100
# 164/164 - 0s - loss: 0.2861 - accuracy: 0.8787
# Epoch 78/100
# 164/164 - 0s - loss: 0.2898 - accuracy: 0.8749
# Epoch 79/100
# 164/164 - 0s - loss: 0.2797 - accuracy: 0.8835
# Epoch 80/100
# 164/164 - 0s - loss: 0.2803 - accuracy: 0.8806
# Epoch 81/100
# 164/164 - 0s - loss: 0.2820 - accuracy: 0.8779
# Epoch 82/100
# 164/164 - 0s - loss: 0.2800 - accuracy: 0.8800
# Epoch 83/100
# 164/164 - 0s - loss: 0.2836 - accuracy: 0.8795
# Epoch 84/100
# 164/164 - 0s - loss: 0.2774 - accuracy: 0.8837
# Epoch 85/100
# 164/164 - 0s - loss: 0.2860 - accuracy: 0.8734
# Epoch 86/100
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8781
# Epoch 87/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8844
# Epoch 88/100
# 164/164 - 0s - loss: 0.2770 - accuracy: 0.8812
# Epoch 89/100
# 164/164 - 0s - loss: 0.2744 - accuracy: 0.8821
# Epoch 90/100
# 164/164 - 0s - loss: 0.2805 - accuracy: 0.8795
# Epoch 91/100
# 164/164 - 0s - loss: 0.2787 - accuracy: 0.8844
# Epoch 92/100
# 164/164 - 0s - loss: 0.2799 - accuracy: 0.8856
# Epoch 93/100
# 164/164 - 0s - loss: 0.2757 - accuracy: 0.8829
# Epoch 94/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8844
# Epoch 95/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8846
# Epoch 96/100
# 164/164 - 0s - loss: 0.2777 - accuracy: 0.8831
# Epoch 97/100
# 164/164 - 0s - loss: 0.2763 - accuracy: 0.8850
# Epoch 98/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8840
# Epoch 99/100
# 164/164 - 0s - loss: 0.2740 - accuracy: 0.8837
# Epoch 100/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8875

# %%
# scoring the model with more layers

deep_model2_loss, deep_model2_accuracy = deep_model2.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model2_loss}, Accuracy: {deep_model2_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3000 - accuracy: 0.8707
# Normal Neural Network - Loss: 0.29997047781944275, Accuracy: 0.8707093596458435

# %%
# Finding most important features

feat_model = RandomForestClassifier()
feat_model.fit(X_train_scaled, y_train_catagorical)
feats = feat_model.feature_importances_
feat_list = sorted(zip(feats,feature_names), reverse=True)
feat_list
# Out:
# [(0.10609241249936005, 'koi_fpflag_nt'),
#  (0.10490828383393712, 'koi_fpflag_co'),
#  (0.07239708426099763, 'koi_fpflag_ss'),
#  (0.053618395316294185, 'koi_prad'),
#  (0.052256945280473734, 'koi_model_snr'),
#  (0.040349159298171296, 'koi_duration_err2'),
#  (0.03522721436727802, 'koi_fpflag_ec'),
#  (0.034591183465736794, 'koi_duration_err1'),
#  (0.03265592411164437, 'koi_steff_err1'),
#  (0.03154042362046396, 'koi_prad_err2'),
#  (0.02425896131747935, 'koi_prad_err1'),
#  (0.02259951924316135, 'koi_steff_err2'),
#  (0.022265663734593964, 'koi_duration'),
#  (0.022214998514511888, 'koi_depth'),
#  (0.0213132689302937, 'koi_period'),
#  (0.020792771869247585, 'koi_insol_err1'),
#  (0.020656788233389886, 'koi_time0bk_err1'),
#  (0.019599388860085623, 'koi_impact'),
#  (0.0192262905932186, 'koi_time0bk_err2'),
#  (0.0176505973771433, 'koi_period_err2'),
#  (0.017628791439029377, 'koi_period_err1'),
#  (0.016183682397578572, 'koi_teq'),
#  (0.013929580749234182, 'koi_time0bk'),
#  (0.013882238460555052, 'koi_depth_err2'),
#  (0.013728226409192643, 'koi_depth_err1'),
#  (0.013067762498268106, 'koi_insol'),
#  (0.011854769167873046, 'ra'),
#  (0.011605325025172902, 'dec'),
#  (0.011396845188205988, 'koi_srad_err1'),
#  (0.011375077005083117, 'koi_slogg_err2'),
#  (0.011269508576257067, 'koi_impact_err2'),
#  (0.011221082609906294, 'koi_impact_err1'),
#  (0.010262722268435973, 'koi_kepmag'),
#  (0.010135684924624331, 'koi_insol_err2'),
#  (0.009857622327876054, 'koi_steff'),
#  (0.009158733861764074, 'koi_slogg'),
#  (0.009092822281807848, 'koi_srad'),
#  (0.008602277795565341, 'koi_srad_err2'),
#  (0.008453481859397743, 'koi_slogg_err1'),
#  (0.003078490426689875, 'koi_tce_plnt_num')]

# %%
# creating a selected features variable with only the top 15 most important variables

short_feat_list = feat_list[:15]
short_feat_list = list(zip(*short_feat_list))
short_feat_list = list(short_feat_list[1])
tuned_X = df[short_feat_list]
tuned_X.shape
# Out:
# (6991, 15)

# %%
# creating a deep model with the most important variables

# Spliting the tuned data
tuned_X_train, tuned_X_test, y_train, y_test = train_test_split(tuned_X, target, random_state=42)

# Scaling the tuned data
tuned_X_scaler = MinMaxScaler().fit(tuned_X_train)

tuned_X_train_scaled = tuned_X_scaler.transform(tuned_X_train)
tuned_X_test_scaled = tuned_X_scaler.transform(tuned_X_test)

# Retraining the tuned data
tuned_deep_model = Sequential()
tuned_deep_model.add(Dense(units=10, activation='relu', input_dim=15))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=3, activation='softmax'))

# Compiling the tuned data
tuned_deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
tuned_deep_model.fit(tuned_X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.9598 - accuracy: 0.5977
# Epoch 2/100
# 164/164 - 0s - loss: 0.4890 - accuracy: 0.7452
# Epoch 3/100
# 164/164 - 0s - loss: 0.4033 - accuracy: 0.7463
# Epoch 4/100
# 164/164 - 0s - loss: 0.3898 - accuracy: 0.7776
# Epoch 5/100
# 164/164 - 0s - loss: 0.3843 - accuracy: 0.7858
# Epoch 6/100
# 164/164 - 0s - loss: 0.3791 - accuracy: 0.7860
# Epoch 7/100
# 164/164 - 0s - loss: 0.3749 - accuracy: 0.7934
# Epoch 8/100
# 164/164 - 0s - loss: 0.3712 - accuracy: 0.8049
# Epoch 9/100
# 164/164 - 0s - loss: 0.3668 - accuracy: 0.8039
# Epoch 10/100
# 164/164 - 0s - loss: 0.3613 - accuracy: 0.8190
# Epoch 11/100
# 164/164 - 0s - loss: 0.3578 - accuracy: 0.8200
# Epoch 12/100
# 164/164 - 0s - loss: 0.3511 - accuracy: 0.8228
# Epoch 13/100
# 164/164 - 0s - loss: 0.3483 - accuracy: 0.8270
# Epoch 14/100
# 164/164 - 0s - loss: 0.3459 - accuracy: 0.8291
# Epoch 15/100
# 164/164 - 0s - loss: 0.3436 - accuracy: 0.8327
# Epoch 16/100
# 164/164 - 0s - loss: 0.3393 - accuracy: 0.8354
# Epoch 17/100
# 164/164 - 0s - loss: 0.3371 - accuracy: 0.8396
# Epoch 18/100
# 164/164 - 0s - loss: 0.3331 - accuracy: 0.8388
# Epoch 19/100
# 164/164 - 0s - loss: 0.3323 - accuracy: 0.8392
# Epoch 20/100
# 164/164 - 0s - loss: 0.3293 - accuracy: 0.8411
# Epoch 21/100
# 164/164 - 0s - loss: 0.3254 - accuracy: 0.8432
# Epoch 22/100
# 164/164 - 0s - loss: 0.3232 - accuracy: 0.8459
# Epoch 23/100
# 164/164 - 0s - loss: 0.3191 - accuracy: 0.8482
# Epoch 24/100
# 164/164 - 0s - loss: 0.3172 - accuracy: 0.8533
# Epoch 25/100
# 164/164 - 0s - loss: 0.3154 - accuracy: 0.8518
# Epoch 26/100
# 164/164 - 0s - loss: 0.3129 - accuracy: 0.8510
# Epoch 27/100
# 164/164 - 0s - loss: 0.3072 - accuracy: 0.8577
# Epoch 28/100
# 164/164 - 0s - loss: 0.3101 - accuracy: 0.8549
# Epoch 29/100
# 164/164 - 0s - loss: 0.3030 - accuracy: 0.8642
# Epoch 30/100
# 164/164 - 0s - loss: 0.3024 - accuracy: 0.8623
# Epoch 31/100
# 164/164 - 0s - loss: 0.2980 - accuracy: 0.8623
# Epoch 32/100
# 164/164 - 0s - loss: 0.2953 - accuracy: 0.8680
# Epoch 33/100
# 164/164 - 0s - loss: 0.2919 - accuracy: 0.8728
# Epoch 34/100
# 164/164 - 0s - loss: 0.2878 - accuracy: 0.8743
# Epoch 35/100
# 164/164 - 0s - loss: 0.2933 - accuracy: 0.8667
# Epoch 36/100
# 164/164 - 0s - loss: 0.2843 - accuracy: 0.8755
# Epoch 37/100
# 164/164 - 0s - loss: 0.2886 - accuracy: 0.8718
# Epoch 38/100
# 164/164 - 0s - loss: 0.2852 - accuracy: 0.8753
# Epoch 39/100
# 164/164 - 0s - loss: 0.2828 - accuracy: 0.8772
# Epoch 40/100
# 164/164 - 0s - loss: 0.2807 - accuracy: 0.8777
# Epoch 41/100
# 164/164 - 0s - loss: 0.2832 - accuracy: 0.8766
# Epoch 42/100
# 164/164 - 0s - loss: 0.2800 - accuracy: 0.8793
# Epoch 43/100
# 164/164 - 0s - loss: 0.2795 - accuracy: 0.8789
# Epoch 44/100
# 164/164 - 0s - loss: 0.2804 - accuracy: 0.8800
# Epoch 45/100
# 164/164 - 0s - loss: 0.2815 - accuracy: 0.8770
# Epoch 46/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8772
# Epoch 47/100
# 164/164 - 0s - loss: 0.2845 - accuracy: 0.8735
# Epoch 48/100
# 164/164 - 0s - loss: 0.2820 - accuracy: 0.8737
# Epoch 49/100
# 164/164 - 0s - loss: 0.2802 - accuracy: 0.8793
# Epoch 50/100
# 164/164 - 0s - loss: 0.2781 - accuracy: 0.8789
# Epoch 51/100
# 164/164 - 0s - loss: 0.2800 - accuracy: 0.8808
# Epoch 52/100
# 164/164 - 0s - loss: 0.2745 - accuracy: 0.8840
# Epoch 53/100
# 164/164 - 0s - loss: 0.2765 - accuracy: 0.8779
# Epoch 54/100
# 164/164 - 0s - loss: 0.2743 - accuracy: 0.8819
# Epoch 55/100
# 164/164 - 0s - loss: 0.2779 - accuracy: 0.8791
# Epoch 56/100
# 164/164 - 0s - loss: 0.2764 - accuracy: 0.8804
# Epoch 57/100
# 164/164 - 0s - loss: 0.2764 - accuracy: 0.8812
# Epoch 58/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8831
# Epoch 59/100
# 164/164 - 0s - loss: 0.2765 - accuracy: 0.8838
# Epoch 60/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8835
# Epoch 61/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8798
# Epoch 62/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8831
# Epoch 63/100
# 164/164 - 0s - loss: 0.2739 - accuracy: 0.8861
# Epoch 64/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8802
# Epoch 65/100
# 164/164 - 0s - loss: 0.2738 - accuracy: 0.8806
# Epoch 66/100
# 164/164 - 0s - loss: 0.2713 - accuracy: 0.8833
# Epoch 67/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8793
# Epoch 68/100
# 164/164 - 0s - loss: 0.2746 - accuracy: 0.8802
# Epoch 69/100
# 164/164 - 0s - loss: 0.2760 - accuracy: 0.8781
# Epoch 70/100
# 164/164 - 0s - loss: 0.2767 - accuracy: 0.8810
# Epoch 71/100
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8783
# Epoch 72/100
# 164/164 - 0s - loss: 0.2734 - accuracy: 0.8804
# Epoch 73/100
# 164/164 - 0s - loss: 0.2748 - accuracy: 0.8819
# Epoch 74/100
# 164/164 - 0s - loss: 0.2730 - accuracy: 0.8833
# Epoch 75/100
# 164/164 - 0s - loss: 0.2737 - accuracy: 0.8846
# Epoch 76/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8814
# Epoch 77/100
# 164/164 - 0s - loss: 0.2743 - accuracy: 0.8814
# Epoch 78/100
# 164/164 - 0s - loss: 0.2720 - accuracy: 0.8825
# Epoch 79/100
# 164/164 - 0s - loss: 0.2768 - accuracy: 0.8800
# Epoch 80/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8829
# Epoch 81/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8829
# Epoch 82/100
# 164/164 - 0s - loss: 0.2704 - accuracy: 0.8850
# Epoch 83/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8789
# Epoch 84/100
# 164/164 - 0s - loss: 0.2718 - accuracy: 0.8844
# Epoch 85/100
# 164/164 - 0s - loss: 0.2730 - accuracy: 0.8831
# Epoch 86/100
# 164/164 - 0s - loss: 0.2772 - accuracy: 0.8796
# Epoch 87/100
# 164/164 - 0s - loss: 0.2719 - accuracy: 0.8819
# Epoch 88/100
# 164/164 - 0s - loss: 0.2709 - accuracy: 0.8867
# Epoch 89/100
# 164/164 - 0s - loss: 0.2768 - accuracy: 0.8789
# Epoch 90/100
# 164/164 - 0s - loss: 0.2718 - accuracy: 0.8840
# Epoch 91/100
# 164/164 - 0s - loss: 0.2721 - accuracy: 0.8817
# Epoch 92/100
# 164/164 - 0s - loss: 0.2691 - accuracy: 0.8827
# Epoch 93/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8825
# Epoch 94/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8827
# Epoch 95/100
# 164/164 - 0s - loss: 0.2703 - accuracy: 0.8863
# Epoch 96/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8793
# Epoch 97/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8772
# Epoch 98/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8779
# Epoch 99/100
# 164/164 - 0s - loss: 0.2732 - accuracy: 0.8825
# Epoch 100/100
# 164/164 - 0s - loss: 0.2746 - accuracy: 0.8835

# %%
# Scoring the tuned data
tuned_deep_model_loss, tuned_deep_model_accuracy = tuned_deep_model.evaluate(tuned_X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {tuned_deep_model_loss}, Accuracy: {tuned_deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3009 - accuracy: 0.8741
# Normal Neural Network - Loss: 0.30088040232658386, Accuracy: 0.8741418719291687
