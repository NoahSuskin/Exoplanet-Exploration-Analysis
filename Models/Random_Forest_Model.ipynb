# %%
# Update sklearn to prevent version mismatches

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
file_path = '../Resources/exoplanet_data.csv'

df = pd.read_csv(file_path)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
target = df['koi_disposition']
selected_features = df.drop(['koi_disposition'], axis=1)
# Selected Feature Names
feature_names = selected_features.columns.tolist()

# selected_features.head()
feature_names

# Encoding
# dummy = pd.get_dummies(target, columns=["koi_disposition"])
# target.unique()
# Can't encode
# Out:
# ['koi_fpflag_nt',
#  'koi_fpflag_ss',
#  'koi_fpflag_co',
#  'koi_fpflag_ec',
#  'koi_period',
#  'koi_period_err1',
#  'koi_period_err2',
#  'koi_time0bk',
#  'koi_time0bk_err1',
#  'koi_time0bk_err2',
#  'koi_impact',
#  'koi_impact_err1',
#  'koi_impact_err2',
#  'koi_duration',
#  'koi_duration_err1',
#  'koi_duration_err2',
#  'koi_depth',
#  'koi_depth_err1',
#  'koi_depth_err2',
#  'koi_prad',
#  'koi_prad_err1',
#  'koi_prad_err2',
#  'koi_teq',
#  'koi_insol',
#  'koi_insol_err1',
#  'koi_insol_err2',
#  'koi_model_snr',
#  'koi_tce_plnt_num',
#  'koi_steff',
#  'koi_steff_err1',
#  'koi_steff_err2',
#  'koi_slogg',
#  'koi_slogg_err1',
#  'koi_slogg_err2',
#  'koi_srad',
#  'koi_srad_err1',
#  'koi_srad_err2',
#  'ra',
#  'dec',
#  'koi_kepmag']

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X_train, X_test, y_train, y_test = train_test_split(selected_features, target, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data

X_scaler = StandardScaler().fit(X_train)

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# # Train the Model

# %%
# Using a random forest
model = RandomForestClassifier()
model.fit(X_train_scaled, y_train)
feats = model.feature_importances_

print(f"Training Data Score: {model.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model.score(X_test_scaled, y_test)}")


feat_list = sorted(zip(feats,feature_names), reverse=True)
feat_list
# Out:
# Training Data Score: 1.0
# Testing Data Score: 0.9033180778032036
# [(0.10586310311475158, 'koi_fpflag_co'),
#  (0.10290663194692916, 'koi_fpflag_nt'),
#  (0.07405766849435513, 'koi_fpflag_ss'),
#  (0.05774190451365316, 'koi_model_snr'),
#  (0.04634287962564856, 'koi_prad'),
#  (0.03920684930892871, 'koi_fpflag_ec'),
#  (0.0321588381772195, 'koi_duration_err2'),
#  (0.03115986689795736, 'koi_steff_err1'),
#  (0.030117415000382893, 'koi_duration_err1'),
#  (0.028943640014883133, 'koi_prad_err2'),
#  (0.025829514231287036, 'koi_steff_err2'),
#  (0.025596330092447286, 'koi_prad_err1'),
#  (0.025538112635883934, 'koi_depth'),
#  (0.023343112853747017, 'koi_time0bk_err2'),
#  (0.022256220726754664, 'koi_time0bk_err1'),
#  (0.021334695656846644, 'koi_period_err1'),
#  (0.020497901329168015, 'koi_duration'),
#  (0.020232032591075463, 'koi_period_err2'),
#  (0.019578669079328932, 'koi_insol_err1'),
#  (0.018247039400068867, 'koi_impact'),
#  (0.017899433257289033, 'koi_period'),
#  (0.017406374922587616, 'koi_insol'),
#  (0.014957474612892754, 'koi_insol_err2'),
#  (0.014591420879766757, 'koi_teq'),
#  (0.01389204035846081, 'koi_srad_err1'),
#  (0.013215151096938478, 'koi_depth_err1'),
#  (0.013198218060287233, 'koi_time0bk'),
#  (0.01266524116697519, 'koi_depth_err2'),
#  (0.011608095715043445, 'ra'),
#  (0.011490459234822415, 'dec'),
#  (0.01148618045046322, 'koi_impact_err1'),
#  (0.011001103007199258, 'koi_impact_err2'),
#  (0.009745893210071492, 'koi_kepmag'),
#  (0.00945597140209169, 'koi_slogg_err2'),
#  (0.009121989872099884, 'koi_slogg'),
#  (0.009017807413194658, 'koi_steff'),
#  (0.008587286176365264, 'koi_srad'),
#  (0.008584189571726035, 'koi_srad_err2'),
#  (0.008401215990843506, 'koi_slogg_err1'),
#  (0.002722027909564234, 'koi_tce_plnt_num')]

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
             'n_estimators': [100, 200, 300]}
grid = GridSearchCV(model, param_grid, cv=3)
grid.fit(X_train_scaled, y_train)

# %%
# Train the model with GridSearch

# %%
print(grid.best_params_)
print(grid.best_score_)

# %% [markdown]
# # Tuning the model based on different features

# %%
# Using only top 15 most important variables based on the RandomForest Importance features method

# Selecting top 15 most important variables
short_feat_list = feat_list[:15]
short_feat_list = list(zip(*short_feat_list))
short_feat_list = list(short_feat_list[1])
tuned_X = df[short_feat_list]

# Spliting the new data
tuned_X_train, tuned_X_test, y_train, y_test = train_test_split(tuned_X, target, random_state=42)

# Scaling the new data
tuned_X_scaler = StandardScaler().fit(tuned_X_train)

tuned_X_train_scaled = tuned_X_scaler.transform(tuned_X_train)
tuned_X_test_scaled = tuned_X_scaler.transform(tuned_X_test)

# Retraining the new data
tuned_model = RandomForestClassifier()
tuned_model.fit(tuned_X_train_scaled, y_train)
print(f'Tuned Model Score Before Grid Search: {tuned_model.score(tuned_X_test_scaled, y_test)}')

# Using grid search to find the best params
param_grid = {'max_features': ['auto', 'sqrt', 'log2'],
             'n_estimators': [100, 200, 300, 400]}
tuned_grid = GridSearchCV(tuned_model, param_grid, cv=3)
tuned_grid.fit(tuned_X_train_scaled, y_train)
print('-'*12)
print(f'Best Params: {tuned_grid.best_params_}')
print(f'Grid Best Score: {tuned_grid.best_score_}')

# %%
# See which one does the best
from sklearn.metrics import classification_report

# model with all variables
prediction = grid.predict(X_test_scaled)
print(classification_report(y_test, prediction))

# %%
# model with only top 15 variables

tuned_prediction = tuned_grid.predict(tuned_X_test_scaled)
print(classification_report(y_test, tuned_prediction))

# %%
# All models are basically the same
# test with base model

base_predict = model.predict(X_test_scaled)
print(classification_report(y_test, base_predict))

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash

# REMEBER THIS

# import joblib
# filename = 'your_name.sav'
# joblib.dump(your_model, filename)
