# %%
from numpy.random import seed
seed(1)
import pandas as pd
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# loading data into a dataframe

file_path = '../Resources/exoplanet_data.csv'

df = pd.read_csv(file_path)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Setting features and target
target = df['koi_disposition']
selected_features = df.drop(['koi_disposition'], axis=1)

# Selected Feature Names
feature_names = selected_features.columns.tolist()

# looking at the shape of the variables
print(target.shape, selected_features.shape)
# Out:
# (6991,) (6991, 40)

# %%
# Splitting the data into a training set and testing set and scaling

X_train, X_test, y_train, y_test = train_test_split(selected_features, target, random_state=42)

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Encoding the target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Converting the encoded target variable into a catagorical form
y_train_catagorical = to_categorical(encoded_y_train)
y_test_catagorical = to_categorical(encoded_y_test)

# %%
# Creating the deep model

deep_model = Sequential()
deep_model.add(Dense(units=10, activation='relu', input_dim=40))
deep_model.add(Dense(units=10, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model

deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.9325 - accuracy: 0.5085
# Epoch 2/100
# 164/164 - 0s - loss: 0.6682 - accuracy: 0.6889
# Epoch 3/100
# 164/164 - 0s - loss: 0.4936 - accuracy: 0.7503
# Epoch 4/100
# 164/164 - 0s - loss: 0.4324 - accuracy: 0.7612
# Epoch 5/100
# 164/164 - 0s - loss: 0.4088 - accuracy: 0.7871
# Epoch 6/100
# 164/164 - 0s - loss: 0.3959 - accuracy: 0.8070
# Epoch 7/100
# 164/164 - 0s - loss: 0.3880 - accuracy: 0.8123
# Epoch 8/100
# 164/164 - 0s - loss: 0.3813 - accuracy: 0.8138
# Epoch 9/100
# 164/164 - 0s - loss: 0.3749 - accuracy: 0.8215
# Epoch 10/100
# 164/164 - 0s - loss: 0.3670 - accuracy: 0.8262
# Epoch 11/100
# 164/164 - 0s - loss: 0.3608 - accuracy: 0.8268
# Epoch 12/100
# 164/164 - 0s - loss: 0.3542 - accuracy: 0.8289
# Epoch 13/100
# 164/164 - 0s - loss: 0.3462 - accuracy: 0.8360
# Epoch 14/100
# 164/164 - 0s - loss: 0.3429 - accuracy: 0.8329
# Epoch 15/100
# 164/164 - 0s - loss: 0.3388 - accuracy: 0.8337
# Epoch 16/100
# 164/164 - 0s - loss: 0.3330 - accuracy: 0.8402
# Epoch 17/100
# 164/164 - 0s - loss: 0.3303 - accuracy: 0.8409
# Epoch 18/100
# 164/164 - 0s - loss: 0.3296 - accuracy: 0.8394
# Epoch 19/100
# 164/164 - 0s - loss: 0.3262 - accuracy: 0.8404
# Epoch 20/100
# 164/164 - 0s - loss: 0.3243 - accuracy: 0.8447
# Epoch 21/100
# 164/164 - 0s - loss: 0.3218 - accuracy: 0.8457
# Epoch 22/100
# 164/164 - 0s - loss: 0.3199 - accuracy: 0.8463
# Epoch 23/100
# 164/164 - 0s - loss: 0.3166 - accuracy: 0.8488
# Epoch 24/100
# 164/164 - 0s - loss: 0.3143 - accuracy: 0.8533
# Epoch 25/100
# 164/164 - 0s - loss: 0.3110 - accuracy: 0.8564
# Epoch 26/100
# 164/164 - 0s - loss: 0.3120 - accuracy: 0.8539
# Epoch 27/100
# 164/164 - 0s - loss: 0.3089 - accuracy: 0.8566
# Epoch 28/100
# 164/164 - 0s - loss: 0.3068 - accuracy: 0.8589
# Epoch 29/100
# 164/164 - 0s - loss: 0.3035 - accuracy: 0.8634
# Epoch 30/100
# 164/164 - 0s - loss: 0.3031 - accuracy: 0.8606
# Epoch 31/100
# 164/164 - 0s - loss: 0.3000 - accuracy: 0.8642
# Epoch 32/100
# 164/164 - 0s - loss: 0.3019 - accuracy: 0.8617
# Epoch 33/100
# 164/164 - 0s - loss: 0.2977 - accuracy: 0.8663
# Epoch 34/100
# 164/164 - 0s - loss: 0.2970 - accuracy: 0.8627
# Epoch 35/100
# 164/164 - 0s - loss: 0.2944 - accuracy: 0.8682
# Epoch 36/100
# 164/164 - 0s - loss: 0.2922 - accuracy: 0.8711
# Epoch 37/100
# 164/164 - 0s - loss: 0.2925 - accuracy: 0.8678
# Epoch 38/100
# 164/164 - 0s - loss: 0.2906 - accuracy: 0.8692
# Epoch 39/100
# 164/164 - 0s - loss: 0.2917 - accuracy: 0.8684
# Epoch 40/100
# 164/164 - 0s - loss: 0.2905 - accuracy: 0.8693
# Epoch 41/100
# 164/164 - 0s - loss: 0.2886 - accuracy: 0.8734
# Epoch 42/100
# 164/164 - 0s - loss: 0.2888 - accuracy: 0.8739
# Epoch 43/100
# 164/164 - 0s - loss: 0.2876 - accuracy: 0.8724
# Epoch 44/100
# 164/164 - 0s - loss: 0.2829 - accuracy: 0.8728
# Epoch 45/100
# 164/164 - 0s - loss: 0.2844 - accuracy: 0.8779
# Epoch 46/100
# 164/164 - 0s - loss: 0.2833 - accuracy: 0.8747
# Epoch 47/100
# 164/164 - 0s - loss: 0.2834 - accuracy: 0.8802
# Epoch 48/100
# 164/164 - 0s - loss: 0.2801 - accuracy: 0.8781
# Epoch 49/100
# 164/164 - 0s - loss: 0.2804 - accuracy: 0.8755
# Epoch 50/100
# 164/164 - 0s - loss: 0.2804 - accuracy: 0.8776
# Epoch 51/100
# 164/164 - 0s - loss: 0.2780 - accuracy: 0.8762
# Epoch 52/100
# 164/164 - 0s - loss: 0.2779 - accuracy: 0.8762
# Epoch 53/100
# 164/164 - 0s - loss: 0.2774 - accuracy: 0.8808
# Epoch 54/100
# 164/164 - 0s - loss: 0.2774 - accuracy: 0.8798
# Epoch 55/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8814
# Epoch 56/100
# 164/164 - 0s - loss: 0.2736 - accuracy: 0.8838
# Epoch 57/100
# 164/164 - 0s - loss: 0.2732 - accuracy: 0.8833
# Epoch 58/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8764
# Epoch 59/100
# 164/164 - 0s - loss: 0.2716 - accuracy: 0.8835
# Epoch 60/100
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8795
# Epoch 61/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8791
# Epoch 62/100
# 164/164 - 0s - loss: 0.2701 - accuracy: 0.8858
# Epoch 63/100
# 164/164 - 0s - loss: 0.2714 - accuracy: 0.8827
# Epoch 64/100
# 164/164 - 0s - loss: 0.2689 - accuracy: 0.8859
# Epoch 65/100
# 164/164 - 0s - loss: 0.2703 - accuracy: 0.8842
# Epoch 66/100
# 164/164 - 0s - loss: 0.2698 - accuracy: 0.8823
# Epoch 67/100
# 164/164 - 0s - loss: 0.2726 - accuracy: 0.8842
# Epoch 68/100
# 164/164 - 0s - loss: 0.2675 - accuracy: 0.8831
# Epoch 69/100
# 164/164 - 0s - loss: 0.2681 - accuracy: 0.8848
# Epoch 70/100
# 164/164 - 0s - loss: 0.2674 - accuracy: 0.8850
# Epoch 71/100
# 164/164 - 0s - loss: 0.2669 - accuracy: 0.8854
# Epoch 72/100
# 164/164 - 0s - loss: 0.2661 - accuracy: 0.8869
# Epoch 73/100
# 164/164 - 0s - loss: 0.2656 - accuracy: 0.8867
# Epoch 74/100
# 164/164 - 0s - loss: 0.2631 - accuracy: 0.8882
# Epoch 75/100
# 164/164 - 0s - loss: 0.2682 - accuracy: 0.8844
# Epoch 76/100
# 164/164 - 0s - loss: 0.2667 - accuracy: 0.8859
# Epoch 77/100
# 164/164 - 0s - loss: 0.2634 - accuracy: 0.8880
# Epoch 78/100
# 164/164 - 0s - loss: 0.2640 - accuracy: 0.8867
# Epoch 79/100
# 164/164 - 0s - loss: 0.2615 - accuracy: 0.8877
# Epoch 80/100
# 164/164 - 0s - loss: 0.2606 - accuracy: 0.8917
# Epoch 81/100
# 164/164 - 0s - loss: 0.2636 - accuracy: 0.8863
# Epoch 82/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8877
# Epoch 83/100
# 164/164 - 0s - loss: 0.2635 - accuracy: 0.8846
# Epoch 84/100
# 164/164 - 0s - loss: 0.2616 - accuracy: 0.8858
# Epoch 85/100
# 164/164 - 0s - loss: 0.2629 - accuracy: 0.8894
# Epoch 86/100
# 164/164 - 0s - loss: 0.2600 - accuracy: 0.8936
# Epoch 87/100
# 164/164 - 0s - loss: 0.2606 - accuracy: 0.8896
# Epoch 88/100
# 164/164 - 0s - loss: 0.2584 - accuracy: 0.8892
# Epoch 89/100
# 164/164 - 0s - loss: 0.2590 - accuracy: 0.8924
# Epoch 90/100
# 164/164 - 0s - loss: 0.2594 - accuracy: 0.8888
# Epoch 91/100
# 164/164 - 0s - loss: 0.2606 - accuracy: 0.8886
# Epoch 92/100
# 164/164 - 0s - loss: 0.2610 - accuracy: 0.8896
# Epoch 93/100
# 164/164 - 0s - loss: 0.2585 - accuracy: 0.8882
# Epoch 94/100
# 164/164 - 0s - loss: 0.2578 - accuracy: 0.8907
# Epoch 95/100
# 164/164 - 0s - loss: 0.2578 - accuracy: 0.8903
# Epoch 96/100
# 164/164 - 0s - loss: 0.2604 - accuracy: 0.8905
# Epoch 97/100
# 164/164 - 0s - loss: 0.2580 - accuracy: 0.8877
# Epoch 98/100
# 164/164 - 0s - loss: 0.2584 - accuracy: 0.8901
# Epoch 99/100
# 164/164 - 0s - loss: 0.2573 - accuracy: 0.8915
# Epoch 100/100
# 164/164 - 0s - loss: 0.2592 - accuracy: 0.8877

# %%
# scoring the model

deep_model_loss, deep_model_accuracy = deep_model.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2838 - accuracy: 0.8867
# Normal Neural Network - Loss: 0.2838209569454193, Accuracy: 0.8867276906967163

# %%
# Creating a model with more neural layers

deep_model2 = Sequential()
deep_model2.add(Dense(units=10, activation='relu', input_dim=40))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model with more layers

deep_model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model2.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.7920 - accuracy: 0.6384
# Epoch 2/100
# 164/164 - 0s - loss: 0.3974 - accuracy: 0.7589
# Epoch 3/100
# 164/164 - 0s - loss: 0.3898 - accuracy: 0.7677
# Epoch 4/100
# 164/164 - 0s - loss: 0.3791 - accuracy: 0.7980
# Epoch 5/100
# 164/164 - 0s - loss: 0.3769 - accuracy: 0.8087
# Epoch 6/100
# 164/164 - 0s - loss: 0.3766 - accuracy: 0.8039
# Epoch 7/100
# 164/164 - 0s - loss: 0.3722 - accuracy: 0.8224
# Epoch 8/100
# 164/164 - 0s - loss: 0.3677 - accuracy: 0.8142
# Epoch 9/100
# 164/164 - 0s - loss: 0.3659 - accuracy: 0.8262
# Epoch 10/100
# 164/164 - 0s - loss: 0.3701 - accuracy: 0.8138
# Epoch 11/100
# 164/164 - 0s - loss: 0.3635 - accuracy: 0.8226
# Epoch 12/100
# 164/164 - 0s - loss: 0.3616 - accuracy: 0.8228
# Epoch 13/100
# 164/164 - 0s - loss: 0.3607 - accuracy: 0.8255
# Epoch 14/100
# 164/164 - 0s - loss: 0.3616 - accuracy: 0.8205
# Epoch 15/100
# 164/164 - 0s - loss: 0.3598 - accuracy: 0.8198
# Epoch 16/100
# 164/164 - 0s - loss: 0.3565 - accuracy: 0.8274
# Epoch 17/100
# 164/164 - 0s - loss: 0.3567 - accuracy: 0.8253
# Epoch 18/100
# 164/164 - 0s - loss: 0.3528 - accuracy: 0.8253
# Epoch 19/100
# 164/164 - 0s - loss: 0.3512 - accuracy: 0.8230
# Epoch 20/100
# 164/164 - 0s - loss: 0.3538 - accuracy: 0.8287
# Epoch 21/100
# 164/164 - 0s - loss: 0.3458 - accuracy: 0.8348
# Epoch 22/100
# 164/164 - 0s - loss: 0.3464 - accuracy: 0.8318
# Epoch 23/100
# 164/164 - 0s - loss: 0.3450 - accuracy: 0.8285
# Epoch 24/100
# 164/164 - 0s - loss: 0.3473 - accuracy: 0.8283
# Epoch 25/100
# 164/164 - 0s - loss: 0.3400 - accuracy: 0.8344
# Epoch 26/100
# 164/164 - 0s - loss: 0.3429 - accuracy: 0.8280
# Epoch 27/100
# 164/164 - 0s - loss: 0.3409 - accuracy: 0.8312
# Epoch 28/100
# 164/164 - 0s - loss: 0.3425 - accuracy: 0.8320
# Epoch 29/100
# 164/164 - 0s - loss: 0.3445 - accuracy: 0.8308
# Epoch 30/100
# 164/164 - 0s - loss: 0.3337 - accuracy: 0.8398
# Epoch 31/100
# 164/164 - 0s - loss: 0.3317 - accuracy: 0.8367
# Epoch 32/100
# 164/164 - 0s - loss: 0.3305 - accuracy: 0.8369
# Epoch 33/100
# 164/164 - 0s - loss: 0.3316 - accuracy: 0.8371
# Epoch 34/100
# 164/164 - 0s - loss: 0.3311 - accuracy: 0.8421
# Epoch 35/100
# 164/164 - 0s - loss: 0.3259 - accuracy: 0.8394
# Epoch 36/100
# 164/164 - 0s - loss: 0.3259 - accuracy: 0.8428
# Epoch 37/100
# 164/164 - 0s - loss: 0.3253 - accuracy: 0.8432
# Epoch 38/100
# 164/164 - 0s - loss: 0.3283 - accuracy: 0.8440
# Epoch 39/100
# 164/164 - 0s - loss: 0.3283 - accuracy: 0.8419
# Epoch 40/100
# 164/164 - 0s - loss: 0.3281 - accuracy: 0.8413
# Epoch 41/100
# 164/164 - 0s - loss: 0.3191 - accuracy: 0.8472
# Epoch 42/100
# 164/164 - 0s - loss: 0.3149 - accuracy: 0.8535
# Epoch 43/100
# 164/164 - 0s - loss: 0.3173 - accuracy: 0.8476
# Epoch 44/100
# 164/164 - 0s - loss: 0.3184 - accuracy: 0.8507
# Epoch 45/100
# 164/164 - 0s - loss: 0.3138 - accuracy: 0.8529
# Epoch 46/100
# 164/164 - 0s - loss: 0.3122 - accuracy: 0.8564
# Epoch 47/100
# 164/164 - 0s - loss: 0.3093 - accuracy: 0.8589
# Epoch 48/100
# 164/164 - 0s - loss: 0.3114 - accuracy: 0.8564
# Epoch 49/100
# 164/164 - 0s - loss: 0.3043 - accuracy: 0.8604
# Epoch 50/100
# 164/164 - 0s - loss: 0.3016 - accuracy: 0.8646
# Epoch 51/100
# 164/164 - 0s - loss: 0.3020 - accuracy: 0.8644
# Epoch 52/100
# 164/164 - 0s - loss: 0.3045 - accuracy: 0.8602
# Epoch 53/100
# 164/164 - 0s - loss: 0.3014 - accuracy: 0.8629
# Epoch 54/100
# 164/164 - 0s - loss: 0.2976 - accuracy: 0.8665
# Epoch 55/100
# 164/164 - 0s - loss: 0.2961 - accuracy: 0.8690
# Epoch 56/100
# 164/164 - 0s - loss: 0.2922 - accuracy: 0.8678
# Epoch 57/100
# 164/164 - 0s - loss: 0.3008 - accuracy: 0.8686
# Epoch 58/100
# 164/164 - 0s - loss: 0.2909 - accuracy: 0.8711
# Epoch 59/100
# 164/164 - 0s - loss: 0.2890 - accuracy: 0.8739
# Epoch 60/100
# 164/164 - 0s - loss: 0.2900 - accuracy: 0.8739
# Epoch 61/100
# 164/164 - 0s - loss: 0.2944 - accuracy: 0.8684
# Epoch 62/100
# 164/164 - 0s - loss: 0.2891 - accuracy: 0.8716
# Epoch 63/100
# 164/164 - 0s - loss: 0.2968 - accuracy: 0.8636
# Epoch 64/100
# 164/164 - 0s - loss: 0.2885 - accuracy: 0.8718
# Epoch 65/100
# 164/164 - 0s - loss: 0.2900 - accuracy: 0.8753
# Epoch 66/100
# 164/164 - 0s - loss: 0.2891 - accuracy: 0.8720
# Epoch 67/100
# 164/164 - 0s - loss: 0.2895 - accuracy: 0.8745
# Epoch 68/100
# 164/164 - 0s - loss: 0.2817 - accuracy: 0.8800
# Epoch 69/100
# 164/164 - 0s - loss: 0.2845 - accuracy: 0.8779
# Epoch 70/100
# 164/164 - 0s - loss: 0.2781 - accuracy: 0.8817
# Epoch 71/100
# 164/164 - 0s - loss: 0.2855 - accuracy: 0.8714
# Epoch 72/100
# 164/164 - 0s - loss: 0.2791 - accuracy: 0.8795
# Epoch 73/100
# 164/164 - 0s - loss: 0.2786 - accuracy: 0.8795
# Epoch 74/100
# 164/164 - 0s - loss: 0.2816 - accuracy: 0.8793
# Epoch 75/100
# 164/164 - 0s - loss: 0.2787 - accuracy: 0.8796
# Epoch 76/100
# 164/164 - 0s - loss: 0.2783 - accuracy: 0.8796
# Epoch 77/100
# 164/164 - 0s - loss: 0.2824 - accuracy: 0.8787
# Epoch 78/100
# 164/164 - 0s - loss: 0.2809 - accuracy: 0.8791
# Epoch 79/100
# 164/164 - 0s - loss: 0.2762 - accuracy: 0.8796
# Epoch 80/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8789
# Epoch 81/100
# 164/164 - 0s - loss: 0.2797 - accuracy: 0.8768
# Epoch 82/100
# 164/164 - 0s - loss: 0.2774 - accuracy: 0.8785
# Epoch 83/100
# 164/164 - 0s - loss: 0.2730 - accuracy: 0.8842
# Epoch 84/100
# 164/164 - 0s - loss: 0.2746 - accuracy: 0.8802
# Epoch 85/100
# 164/164 - 0s - loss: 0.2733 - accuracy: 0.8831
# Epoch 86/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8852
# Epoch 87/100
# 164/164 - 0s - loss: 0.2702 - accuracy: 0.8867
# Epoch 88/100
# 164/164 - 0s - loss: 0.2720 - accuracy: 0.8804
# Epoch 89/100
# 164/164 - 0s - loss: 0.2688 - accuracy: 0.8850
# Epoch 90/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8821
# Epoch 91/100
# 164/164 - 0s - loss: 0.2714 - accuracy: 0.8823
# Epoch 92/100
# 164/164 - 0s - loss: 0.2680 - accuracy: 0.8817
# Epoch 93/100
# 164/164 - 0s - loss: 0.2717 - accuracy: 0.8825
# Epoch 94/100
# 164/164 - 0s - loss: 0.2694 - accuracy: 0.8884
# Epoch 95/100
# 164/164 - 0s - loss: 0.2673 - accuracy: 0.8852
# Epoch 96/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8859
# Epoch 97/100
# 164/164 - 0s - loss: 0.2716 - accuracy: 0.8858
# Epoch 98/100
# 164/164 - 0s - loss: 0.2669 - accuracy: 0.8867
# Epoch 99/100
# 164/164 - 0s - loss: 0.2657 - accuracy: 0.8882
# Epoch 100/100
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8880

# %%
# scoring the model with more layers

deep_model2_loss, deep_model2_accuracy = deep_model2.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model2_loss}, Accuracy: {deep_model2_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2750 - accuracy: 0.8879
# Normal Neural Network - Loss: 0.27500417828559875, Accuracy: 0.8878718614578247

# %%
# Finding most important features

feat_model = RandomForestClassifier()
feat_model.fit(X_train_scaled, y_train_catagorical)
feats = feat_model.feature_importances_
feat_list = sorted(zip(feats,feature_names), reverse=True)
feat_list
# Out:
# [(0.10609241249936005, 'koi_fpflag_nt'),
#  (0.10490828383393712, 'koi_fpflag_co'),
#  (0.07239708426099763, 'koi_fpflag_ss'),
#  (0.053618395316294185, 'koi_prad'),
#  (0.052256945280473734, 'koi_model_snr'),
#  (0.040349159298171296, 'koi_duration_err2'),
#  (0.03522721436727802, 'koi_fpflag_ec'),
#  (0.034591183465736794, 'koi_duration_err1'),
#  (0.03265592411164437, 'koi_steff_err1'),
#  (0.03154042362046396, 'koi_prad_err2'),
#  (0.02425896131747935, 'koi_prad_err1'),
#  (0.02259951924316135, 'koi_steff_err2'),
#  (0.022265663734593964, 'koi_duration'),
#  (0.022214998514511888, 'koi_depth'),
#  (0.0213132689302937, 'koi_period'),
#  (0.020792771869247585, 'koi_insol_err1'),
#  (0.020656788233389886, 'koi_time0bk_err1'),
#  (0.019599388860085623, 'koi_impact'),
#  (0.0192262905932186, 'koi_time0bk_err2'),
#  (0.0176505973771433, 'koi_period_err2'),
#  (0.017628791439029377, 'koi_period_err1'),
#  (0.016183682397578572, 'koi_teq'),
#  (0.013929580749234182, 'koi_time0bk'),
#  (0.013882238460555052, 'koi_depth_err2'),
#  (0.013728226409192643, 'koi_depth_err1'),
#  (0.013067762498268106, 'koi_insol'),
#  (0.011854769167873046, 'ra'),
#  (0.011605325025172902, 'dec'),
#  (0.011396845188205988, 'koi_srad_err1'),
#  (0.011375077005083117, 'koi_slogg_err2'),
#  (0.011269508576257067, 'koi_impact_err2'),
#  (0.011221082609906294, 'koi_impact_err1'),
#  (0.010262722268435973, 'koi_kepmag'),
#  (0.010135684924624331, 'koi_insol_err2'),
#  (0.009857622327876054, 'koi_steff'),
#  (0.009158733861764074, 'koi_slogg'),
#  (0.009092822281807848, 'koi_srad'),
#  (0.008602277795565341, 'koi_srad_err2'),
#  (0.008453481859397743, 'koi_slogg_err1'),
#  (0.003078490426689875, 'koi_tce_plnt_num')]

# %%
# creating a selected features variable with only the top 15 most important variables!

short_feat_list = feat_list[:15]
short_feat_list = list(zip(*short_feat_list))
short_feat_list = list(short_feat_list[1])
tuned_X = df[short_feat_list]
tuned_X.shape
# Out:
# (6991, 15)

# %%
# creating a deep model with the most important variables

# Spliting the tuned data
tuned_X_train, tuned_X_test, y_train, y_test = train_test_split(tuned_X, target, random_state=42)

# Scaling the tuned data
tuned_X_scaler = MinMaxScaler().fit(tuned_X_train)

tuned_X_train_scaled = tuned_X_scaler.transform(tuned_X_train)
tuned_X_test_scaled = tuned_X_scaler.transform(tuned_X_test)

# Retraining the tuned data
tuned_deep_model = Sequential()
tuned_deep_model.add(Dense(units=10, activation='relu', input_dim=15))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=3, activation='softmax'))

# Compiling the tuned data
tuned_deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
tuned_deep_model.fit(tuned_X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.7870 - accuracy: 0.6956
# Epoch 2/100
# 164/164 - 0s - loss: 0.3965 - accuracy: 0.7612
# Epoch 3/100
# 164/164 - 0s - loss: 0.3860 - accuracy: 0.7915
# Epoch 4/100
# 164/164 - 0s - loss: 0.3786 - accuracy: 0.7969
# Epoch 5/100
# 164/164 - 0s - loss: 0.3679 - accuracy: 0.8140
# Epoch 6/100
# 164/164 - 0s - loss: 0.3627 - accuracy: 0.8102
# Epoch 7/100
# 164/164 - 0s - loss: 0.3630 - accuracy: 0.8116
# Epoch 8/100
# 164/164 - 0s - loss: 0.3545 - accuracy: 0.8253
# Epoch 9/100
# 164/164 - 0s - loss: 0.3544 - accuracy: 0.8188
# Epoch 10/100
# 164/164 - 0s - loss: 0.3503 - accuracy: 0.8270
# Epoch 11/100
# 164/164 - 0s - loss: 0.3526 - accuracy: 0.8171
# Epoch 12/100
# 164/164 - 0s - loss: 0.3486 - accuracy: 0.8264
# Epoch 13/100
# 164/164 - 0s - loss: 0.3453 - accuracy: 0.8270
# Epoch 14/100
# 164/164 - 0s - loss: 0.3475 - accuracy: 0.8274
# Epoch 15/100
# 164/164 - 0s - loss: 0.3430 - accuracy: 0.8341
# Epoch 16/100
# 164/164 - 0s - loss: 0.3425 - accuracy: 0.8356
# Epoch 17/100
# 164/164 - 0s - loss: 0.3386 - accuracy: 0.8379
# Epoch 18/100
# 164/164 - 0s - loss: 0.3387 - accuracy: 0.8341
# Epoch 19/100
# 164/164 - 0s - loss: 0.3386 - accuracy: 0.8350
# Epoch 20/100
# 164/164 - 0s - loss: 0.3350 - accuracy: 0.8423
# Epoch 21/100
# 164/164 - 0s - loss: 0.3361 - accuracy: 0.8402
# Epoch 22/100
# 164/164 - 0s - loss: 0.3303 - accuracy: 0.8453
# Epoch 23/100
# 164/164 - 0s - loss: 0.3327 - accuracy: 0.8373
# Epoch 24/100
# 164/164 - 0s - loss: 0.3274 - accuracy: 0.8482
# Epoch 25/100
# 164/164 - 0s - loss: 0.3237 - accuracy: 0.8484
# Epoch 26/100
# 164/164 - 0s - loss: 0.3255 - accuracy: 0.8447
# Epoch 27/100
# 164/164 - 0s - loss: 0.3173 - accuracy: 0.8535
# Epoch 28/100
# 164/164 - 0s - loss: 0.3164 - accuracy: 0.8491
# Epoch 29/100
# 164/164 - 0s - loss: 0.3133 - accuracy: 0.8562
# Epoch 30/100
# 164/164 - 0s - loss: 0.3098 - accuracy: 0.8581
# Epoch 31/100
# 164/164 - 0s - loss: 0.3103 - accuracy: 0.8591
# Epoch 32/100
# 164/164 - 0s - loss: 0.3080 - accuracy: 0.8577
# Epoch 33/100
# 164/164 - 0s - loss: 0.2991 - accuracy: 0.8690
# Epoch 34/100
# 164/164 - 0s - loss: 0.3046 - accuracy: 0.8617
# Epoch 35/100
# 164/164 - 0s - loss: 0.2951 - accuracy: 0.8711
# Epoch 36/100
# 164/164 - 0s - loss: 0.2994 - accuracy: 0.8678
# Epoch 37/100
# 164/164 - 0s - loss: 0.2963 - accuracy: 0.8690
# Epoch 38/100
# 164/164 - 0s - loss: 0.2949 - accuracy: 0.8713
# Epoch 39/100
# 164/164 - 0s - loss: 0.2931 - accuracy: 0.8697
# Epoch 40/100
# 164/164 - 0s - loss: 0.2918 - accuracy: 0.8749
# Epoch 41/100
# 164/164 - 0s - loss: 0.2898 - accuracy: 0.8743
# Epoch 42/100
# 164/164 - 0s - loss: 0.2994 - accuracy: 0.8629
# Epoch 43/100
# 164/164 - 0s - loss: 0.2933 - accuracy: 0.8722
# Epoch 44/100
# 164/164 - 0s - loss: 0.2954 - accuracy: 0.8682
# Epoch 45/100
# 164/164 - 0s - loss: 0.2894 - accuracy: 0.8753
# Epoch 46/100
# 164/164 - 0s - loss: 0.2910 - accuracy: 0.8699
# Epoch 47/100
# 164/164 - 0s - loss: 0.2893 - accuracy: 0.8734
# Epoch 48/100
# 164/164 - 0s - loss: 0.2918 - accuracy: 0.8697
# Epoch 49/100
# 164/164 - 0s - loss: 0.2912 - accuracy: 0.8728
# Epoch 50/100
# 164/164 - 0s - loss: 0.2902 - accuracy: 0.8734
# Epoch 51/100
# 164/164 - 0s - loss: 0.2898 - accuracy: 0.8711
# Epoch 52/100
# 164/164 - 0s - loss: 0.2853 - accuracy: 0.8760
# Epoch 53/100
# 164/164 - 0s - loss: 0.2896 - accuracy: 0.8728
# Epoch 54/100
# 164/164 - 0s - loss: 0.2901 - accuracy: 0.8734
# Epoch 55/100
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8739
# Epoch 56/100
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8768
# Epoch 57/100
# 164/164 - 0s - loss: 0.2925 - accuracy: 0.8692
# Epoch 58/100
# 164/164 - 0s - loss: 0.2897 - accuracy: 0.8756
# Epoch 59/100
# 164/164 - 0s - loss: 0.2874 - accuracy: 0.8751
# Epoch 60/100
# 164/164 - 0s - loss: 0.2867 - accuracy: 0.8779
# Epoch 61/100
# 164/164 - 0s - loss: 0.2839 - accuracy: 0.8768
# Epoch 62/100
# 164/164 - 0s - loss: 0.2863 - accuracy: 0.8747
# Epoch 63/100
# 164/164 - 0s - loss: 0.2814 - accuracy: 0.8817
# Epoch 64/100
# 164/164 - 0s - loss: 0.2850 - accuracy: 0.8810
# Epoch 65/100
# 164/164 - 0s - loss: 0.2903 - accuracy: 0.8707
# Epoch 66/100
# 164/164 - 0s - loss: 0.2927 - accuracy: 0.8673
# Epoch 67/100
# 164/164 - 0s - loss: 0.2827 - accuracy: 0.8774
# Epoch 68/100
# 164/164 - 0s - loss: 0.2825 - accuracy: 0.8781
# Epoch 69/100
# 164/164 - 0s - loss: 0.2835 - accuracy: 0.8802
# Epoch 70/100
# 164/164 - 0s - loss: 0.2951 - accuracy: 0.8661
# Epoch 71/100
# 164/164 - 0s - loss: 0.2865 - accuracy: 0.8791
# Epoch 72/100
# 164/164 - 0s - loss: 0.2864 - accuracy: 0.8741
# Epoch 73/100
# 164/164 - 0s - loss: 0.2813 - accuracy: 0.8756
# Epoch 74/100
# 164/164 - 0s - loss: 0.2777 - accuracy: 0.8823
# Epoch 75/100
# 164/164 - 0s - loss: 0.2833 - accuracy: 0.8768
# Epoch 76/100
# 164/164 - 0s - loss: 0.2831 - accuracy: 0.8777
# Epoch 77/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8772
# Epoch 78/100
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8722
# Epoch 79/100
# 164/164 - 0s - loss: 0.2808 - accuracy: 0.8756
# Epoch 80/100
# 164/164 - 0s - loss: 0.2766 - accuracy: 0.8816
# Epoch 81/100
# 164/164 - 0s - loss: 0.2810 - accuracy: 0.8747
# Epoch 82/100
# 164/164 - 0s - loss: 0.2792 - accuracy: 0.8779
# Epoch 83/100
# 164/164 - 0s - loss: 0.2842 - accuracy: 0.8770
# Epoch 84/100
# 164/164 - 0s - loss: 0.2801 - accuracy: 0.8774
# Epoch 85/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8781
# Epoch 86/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8800
# Epoch 87/100
# 164/164 - 0s - loss: 0.2797 - accuracy: 0.8808
# Epoch 88/100
# 164/164 - 0s - loss: 0.2806 - accuracy: 0.8749
# Epoch 89/100
# 164/164 - 0s - loss: 0.2792 - accuracy: 0.8762
# Epoch 90/100
# 164/164 - 0s - loss: 0.2777 - accuracy: 0.8793
# Epoch 91/100
# 164/164 - 0s - loss: 0.2809 - accuracy: 0.8768
# Epoch 92/100
# 164/164 - 0s - loss: 0.2798 - accuracy: 0.8783
# Epoch 93/100
# 164/164 - 0s - loss: 0.2820 - accuracy: 0.8774
# Epoch 94/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8804
# Epoch 95/100
# 164/164 - 0s - loss: 0.2749 - accuracy: 0.8795
# Epoch 96/100
# 164/164 - 0s - loss: 0.2752 - accuracy: 0.8819
# Epoch 97/100
# 164/164 - 0s - loss: 0.2776 - accuracy: 0.8781
# Epoch 98/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8785
# Epoch 99/100
# 164/164 - 0s - loss: 0.2755 - accuracy: 0.8785
# Epoch 100/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8806

# %%
# Scoring the tuned data
tuned_deep_model_loss, tuned_deep_model_accuracy = tuned_deep_model.evaluate(tuned_X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {tuned_deep_model_loss}, Accuracy: {tuned_deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2916 - accuracy: 0.8884
# Normal Neural Network - Loss: 0.2916392385959625, Accuracy: 0.8884439468383789

# %%
# Compare the diffent models

print(f'deep_model accuracy: {deep_model_accuracy}')
print(f'deep_model2 accuracy: {deep_model2_accuracy}')
print(f'tuned_deep_model accuracy: {tuned_deep_model_accuracy}')

accuracy_list = [deep_model_accuracy ,deep_model2_accuracy, tuned_deep_model_accuracy]
# Out:
# deep_model accuracy: 0.8867276906967163
# deep_model2 accuracy: 0.8878718614578247
# tuned_deep_model accuracy: 0.8884439468383789

# %%
# Choosing model with highest accuracy
