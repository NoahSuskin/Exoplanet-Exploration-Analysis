# %%
from numpy.random import seed
seed(1)
import pandas as pd
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# loading data into a dataframe

file_path = '../Resources/exoplanet_data.csv'

df = pd.read_csv(file_path)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Setting features and target
target = df['koi_disposition']
selected_features = df.drop(['koi_disposition'], axis=1)

# Selected Feature Names
feature_names = selected_features.columns.tolist()

# looking at the shape of the variables
print(target.shape, selected_features.shape)
# Out:
# (6991,) (6991, 40)

# %%
# Splitting the data into a training set and testing set and scaling

X_train, X_test, y_train, y_test = train_test_split(selected_features, target, random_state=42)

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Encoding the target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Converting the encoded target variable into a catagorical form
y_train_catagorical = to_categorical(encoded_y_train)
y_test_catagorical = to_categorical(encoded_y_test)

# %%
# Creating the deep model

deep_model = Sequential()
deep_model.add(Dense(units=10, activation='relu', input_dim=40))
deep_model.add(Dense(units=10, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model

deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.9352 - accuracy: 0.4946
# Epoch 2/100
# 164/164 - 0s - loss: 0.6548 - accuracy: 0.6813
# Epoch 3/100
# 164/164 - 0s - loss: 0.4864 - accuracy: 0.8011
# Epoch 4/100
# 164/164 - 0s - loss: 0.4022 - accuracy: 0.8198
# Epoch 5/100
# 164/164 - 0s - loss: 0.3753 - accuracy: 0.8198
# Epoch 6/100
# 164/164 - 0s - loss: 0.3629 - accuracy: 0.8272
# Epoch 7/100
# 164/164 - 0s - loss: 0.3554 - accuracy: 0.8272
# Epoch 8/100
# 164/164 - 0s - loss: 0.3480 - accuracy: 0.8341
# Epoch 9/100
# 164/164 - 0s - loss: 0.3444 - accuracy: 0.8274
# Epoch 10/100
# 164/164 - 0s - loss: 0.3390 - accuracy: 0.8352
# Epoch 11/100
# 164/164 - 0s - loss: 0.3360 - accuracy: 0.8360
# Epoch 12/100
# 164/164 - 0s - loss: 0.3331 - accuracy: 0.8415
# Epoch 13/100
# 164/164 - 0s - loss: 0.3295 - accuracy: 0.8432
# Epoch 14/100
# 164/164 - 0s - loss: 0.3267 - accuracy: 0.8440
# Epoch 15/100
# 164/164 - 1s - loss: 0.3253 - accuracy: 0.8425
# Epoch 16/100
# 164/164 - 0s - loss: 0.3244 - accuracy: 0.8442
# Epoch 17/100
# 164/164 - 0s - loss: 0.3222 - accuracy: 0.8470
# Epoch 18/100
# 164/164 - 0s - loss: 0.3211 - accuracy: 0.8426
# Epoch 19/100
# 164/164 - 0s - loss: 0.3185 - accuracy: 0.8501
# Epoch 20/100
# 164/164 - 0s - loss: 0.3184 - accuracy: 0.8507
# Epoch 21/100
# 164/164 - 0s - loss: 0.3146 - accuracy: 0.8507
# Epoch 22/100
# 164/164 - 0s - loss: 0.3169 - accuracy: 0.8486
# Epoch 23/100
# 164/164 - 0s - loss: 0.3167 - accuracy: 0.8476
# Epoch 24/100
# 164/164 - 0s - loss: 0.3121 - accuracy: 0.8526
# Epoch 25/100
# 164/164 - 0s - loss: 0.3109 - accuracy: 0.8564
# Epoch 26/100
# 164/164 - 0s - loss: 0.3090 - accuracy: 0.8568
# Epoch 27/100
# 164/164 - 0s - loss: 0.3076 - accuracy: 0.8577
# Epoch 28/100
# 164/164 - 0s - loss: 0.3061 - accuracy: 0.8562
# Epoch 29/100
# 164/164 - 0s - loss: 0.3063 - accuracy: 0.8556
# Epoch 30/100
# 164/164 - 0s - loss: 0.3043 - accuracy: 0.8575
# Epoch 31/100
# 164/164 - 0s - loss: 0.3027 - accuracy: 0.8600
# Epoch 32/100
# 164/164 - 0s - loss: 0.3031 - accuracy: 0.8608
# Epoch 33/100
# 164/164 - 0s - loss: 0.3028 - accuracy: 0.8611
# Epoch 34/100
# 164/164 - 0s - loss: 0.3015 - accuracy: 0.8629
# Epoch 35/100
# 164/164 - 0s - loss: 0.2993 - accuracy: 0.8629
# Epoch 36/100
# 164/164 - 0s - loss: 0.2987 - accuracy: 0.8592
# Epoch 37/100
# 164/164 - 0s - loss: 0.2970 - accuracy: 0.8646
# Epoch 38/100
# 164/164 - 0s - loss: 0.2957 - accuracy: 0.8663
# Epoch 39/100
# 164/164 - 0s - loss: 0.2961 - accuracy: 0.8671
# Epoch 40/100
# 164/164 - 0s - loss: 0.2971 - accuracy: 0.8652
# Epoch 41/100
# 164/164 - 0s - loss: 0.2939 - accuracy: 0.8695
# Epoch 42/100
# 164/164 - 0s - loss: 0.2953 - accuracy: 0.8661
# Epoch 43/100
# 164/164 - 0s - loss: 0.2927 - accuracy: 0.8709
# Epoch 44/100
# 164/164 - 0s - loss: 0.2949 - accuracy: 0.8692
# Epoch 45/100
# 164/164 - 0s - loss: 0.2936 - accuracy: 0.8680
# Epoch 46/100
# 164/164 - 0s - loss: 0.2919 - accuracy: 0.8728
# Epoch 47/100
# 164/164 - 0s - loss: 0.2899 - accuracy: 0.8724
# Epoch 48/100
# 164/164 - 0s - loss: 0.2903 - accuracy: 0.8663
# Epoch 49/100
# 164/164 - 0s - loss: 0.2926 - accuracy: 0.8680
# Epoch 50/100
# 164/164 - 0s - loss: 0.2879 - accuracy: 0.8728
# Epoch 51/100
# 164/164 - 0s - loss: 0.2883 - accuracy: 0.8705
# Epoch 52/100
# 164/164 - 0s - loss: 0.2882 - accuracy: 0.8711
# Epoch 53/100
# 164/164 - 0s - loss: 0.2864 - accuracy: 0.8732
# Epoch 54/100
# 164/164 - 0s - loss: 0.2855 - accuracy: 0.8713
# Epoch 55/100
# 164/164 - 0s - loss: 0.2863 - accuracy: 0.8711
# Epoch 56/100
# 164/164 - 0s - loss: 0.2856 - accuracy: 0.8716
# Epoch 57/100
# 164/164 - 0s - loss: 0.2844 - accuracy: 0.8732
# Epoch 58/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8753
# Epoch 59/100
# 164/164 - 0s - loss: 0.2854 - accuracy: 0.8747
# Epoch 60/100
# 164/164 - 0s - loss: 0.2842 - accuracy: 0.8741
# Epoch 61/100
# 164/164 - 0s - loss: 0.2816 - accuracy: 0.8772
# Epoch 62/100
# 164/164 - 0s - loss: 0.2823 - accuracy: 0.8749
# Epoch 63/100
# 164/164 - 0s - loss: 0.2822 - accuracy: 0.8751
# Epoch 64/100
# 164/164 - 0s - loss: 0.2820 - accuracy: 0.8796
# Epoch 65/100
# 164/164 - 0s - loss: 0.2828 - accuracy: 0.8734
# Epoch 66/100
# 164/164 - 0s - loss: 0.2804 - accuracy: 0.8762
# Epoch 67/100
# 164/164 - 0s - loss: 0.2823 - accuracy: 0.8774
# Epoch 68/100
# 164/164 - 0s - loss: 0.2807 - accuracy: 0.8776
# Epoch 69/100
# 164/164 - 0s - loss: 0.2796 - accuracy: 0.8779
# Epoch 70/100
# 164/164 - 0s - loss: 0.2799 - accuracy: 0.8787
# Epoch 71/100
# 164/164 - 0s - loss: 0.2798 - accuracy: 0.8749
# Epoch 72/100
# 164/164 - 0s - loss: 0.2831 - accuracy: 0.8724
# Epoch 73/100
# 164/164 - 0s - loss: 0.2787 - accuracy: 0.8758
# Epoch 74/100
# 164/164 - 0s - loss: 0.2778 - accuracy: 0.8760
# Epoch 75/100
# 164/164 - 0s - loss: 0.2796 - accuracy: 0.8770
# Epoch 76/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8762
# Epoch 77/100
# 164/164 - 0s - loss: 0.2795 - accuracy: 0.8764
# Epoch 78/100
# 164/164 - 0s - loss: 0.2776 - accuracy: 0.8789
# Epoch 79/100
# 164/164 - 0s - loss: 0.2780 - accuracy: 0.8798
# Epoch 80/100
# 164/164 - 0s - loss: 0.2820 - accuracy: 0.8770
# Epoch 81/100
# 164/164 - 0s - loss: 0.2796 - accuracy: 0.8760
# Epoch 82/100
# 164/164 - 0s - loss: 0.2768 - accuracy: 0.8796
# Epoch 83/100
# 164/164 - 0s - loss: 0.2756 - accuracy: 0.8796
# Epoch 84/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8808
# Epoch 85/100
# 164/164 - 0s - loss: 0.2763 - accuracy: 0.8762
# Epoch 86/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8789
# Epoch 87/100
# 164/164 - 0s - loss: 0.2761 - accuracy: 0.8848
# Epoch 88/100
# 164/164 - 0s - loss: 0.2764 - accuracy: 0.8793
# Epoch 89/100
# 164/164 - 0s - loss: 0.2738 - accuracy: 0.8802
# Epoch 90/100
# 164/164 - 0s - loss: 0.2756 - accuracy: 0.8789
# Epoch 91/100
# 164/164 - 0s - loss: 0.2756 - accuracy: 0.8795
# Epoch 92/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8796
# Epoch 93/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8779
# Epoch 94/100
# 164/164 - 0s - loss: 0.2756 - accuracy: 0.8781
# Epoch 95/100
# 164/164 - 0s - loss: 0.2738 - accuracy: 0.8835
# Epoch 96/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8810
# Epoch 97/100
# 164/164 - 0s - loss: 0.2738 - accuracy: 0.8806
# Epoch 98/100
# 164/164 - 0s - loss: 0.2722 - accuracy: 0.8844
# Epoch 99/100
# 164/164 - 0s - loss: 0.2729 - accuracy: 0.8806
# Epoch 100/100
# 164/164 - 0s - loss: 0.2748 - accuracy: 0.8804

# %%
# scoring the model

deep_model_loss, deep_model_accuracy = deep_model.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3011 - accuracy: 0.8678
# Normal Neural Network - Loss: 0.30113375186920166, Accuracy: 0.8678489923477173

# %%
# Creating a model with more neural layers

deep_model2 = Sequential()
deep_model2.add(Dense(units=10, activation='relu', input_dim=40))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=10, activation='relu'))
deep_model2.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model with more layers

deep_model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model2.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.9224 - accuracy: 0.5056
# Epoch 2/100
# 164/164 - 0s - loss: 0.4432 - accuracy: 0.7459
# Epoch 3/100
# 164/164 - 0s - loss: 0.3937 - accuracy: 0.7589
# Epoch 4/100
# 164/164 - 0s - loss: 0.3834 - accuracy: 0.7952
# Epoch 5/100
# 164/164 - 0s - loss: 0.3746 - accuracy: 0.8056
# Epoch 6/100
# 164/164 - 0s - loss: 0.3646 - accuracy: 0.8198
# Epoch 7/100
# 164/164 - 0s - loss: 0.3587 - accuracy: 0.8209
# Epoch 8/100
# 164/164 - 0s - loss: 0.3604 - accuracy: 0.8159
# Epoch 9/100
# 164/164 - 0s - loss: 0.3489 - accuracy: 0.8291
# Epoch 10/100
# 164/164 - 0s - loss: 0.3424 - accuracy: 0.8331
# Epoch 11/100
# 164/164 - 0s - loss: 0.3388 - accuracy: 0.8348
# Epoch 12/100
# 164/164 - 0s - loss: 0.3419 - accuracy: 0.8337
# Epoch 13/100
# 164/164 - 0s - loss: 0.3393 - accuracy: 0.8306
# Epoch 14/100
# 164/164 - 0s - loss: 0.3332 - accuracy: 0.8442
# Epoch 15/100
# 164/164 - 0s - loss: 0.3306 - accuracy: 0.8411
# Epoch 16/100
# 164/164 - 0s - loss: 0.3333 - accuracy: 0.8365
# Epoch 17/100
# 164/164 - 0s - loss: 0.3270 - accuracy: 0.8459
# Epoch 18/100
# 164/164 - 0s - loss: 0.3266 - accuracy: 0.8478
# Epoch 19/100
# 164/164 - 0s - loss: 0.3196 - accuracy: 0.8528
# Epoch 20/100
# 164/164 - 0s - loss: 0.3212 - accuracy: 0.8463
# Epoch 21/100
# 164/164 - 0s - loss: 0.3162 - accuracy: 0.8560
# Epoch 22/100
# 164/164 - 0s - loss: 0.3163 - accuracy: 0.8543
# Epoch 23/100
# 164/164 - 0s - loss: 0.3113 - accuracy: 0.8550
# Epoch 24/100
# 164/164 - 0s - loss: 0.3064 - accuracy: 0.8594
# Epoch 25/100
# 164/164 - 0s - loss: 0.3071 - accuracy: 0.8585
# Epoch 26/100
# 164/164 - 0s - loss: 0.3056 - accuracy: 0.8632
# Epoch 27/100
# 164/164 - 0s - loss: 0.2997 - accuracy: 0.8676
# Epoch 28/100
# 164/164 - 0s - loss: 0.2983 - accuracy: 0.8634
# Epoch 29/100
# 164/164 - 0s - loss: 0.3013 - accuracy: 0.8638
# Epoch 30/100
# 164/164 - 0s - loss: 0.3048 - accuracy: 0.8602
# Epoch 31/100
# 164/164 - 0s - loss: 0.2956 - accuracy: 0.8686
# Epoch 32/100
# 164/164 - 0s - loss: 0.2930 - accuracy: 0.8665
# Epoch 33/100
# 164/164 - 0s - loss: 0.2950 - accuracy: 0.8652
# Epoch 34/100
# 164/164 - 0s - loss: 0.2908 - accuracy: 0.8703
# Epoch 35/100
# 164/164 - 0s - loss: 0.2909 - accuracy: 0.8743
# Epoch 36/100
# 164/164 - 0s - loss: 0.2896 - accuracy: 0.8732
# Epoch 37/100
# 164/164 - 0s - loss: 0.2894 - accuracy: 0.8726
# Epoch 38/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8762
# Epoch 39/100
# 164/164 - 0s - loss: 0.2848 - accuracy: 0.8760
# Epoch 40/100
# 164/164 - 0s - loss: 0.2824 - accuracy: 0.8785
# Epoch 41/100
# 164/164 - 0s - loss: 0.2822 - accuracy: 0.8764
# Epoch 42/100
# 164/164 - 0s - loss: 0.2799 - accuracy: 0.8726
# Epoch 43/100
# 164/164 - 0s - loss: 0.2767 - accuracy: 0.8800
# Epoch 44/100
# 164/164 - 0s - loss: 0.2759 - accuracy: 0.8856
# Epoch 45/100
# 164/164 - 0s - loss: 0.2769 - accuracy: 0.8808
# Epoch 46/100
# 164/164 - 0s - loss: 0.2748 - accuracy: 0.8800
# Epoch 47/100
# 164/164 - 0s - loss: 0.2737 - accuracy: 0.8837
# Epoch 48/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8783
# Epoch 49/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8806
# Epoch 50/100
# 164/164 - 0s - loss: 0.2740 - accuracy: 0.8833
# Epoch 51/100
# 164/164 - 0s - loss: 0.2744 - accuracy: 0.8850
# Epoch 52/100
# 164/164 - 0s - loss: 0.2771 - accuracy: 0.8835
# Epoch 53/100
# 164/164 - 0s - loss: 0.2731 - accuracy: 0.8810
# Epoch 54/100
# 164/164 - 0s - loss: 0.2709 - accuracy: 0.8877
# Epoch 55/100
# 164/164 - 0s - loss: 0.2814 - accuracy: 0.8804
# Epoch 56/100
# 164/164 - 0s - loss: 0.2703 - accuracy: 0.8831
# Epoch 57/100
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8856
# Epoch 58/100
# 164/164 - 0s - loss: 0.2726 - accuracy: 0.8823
# Epoch 59/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8827
# Epoch 60/100
# 164/164 - 0s - loss: 0.2655 - accuracy: 0.8892
# Epoch 61/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8880
# Epoch 62/100
# 164/164 - 0s - loss: 0.2704 - accuracy: 0.8838
# Epoch 63/100
# 164/164 - 0s - loss: 0.2656 - accuracy: 0.8888
# Epoch 64/100
# 164/164 - 0s - loss: 0.2769 - accuracy: 0.8823
# Epoch 65/100
# 164/164 - 0s - loss: 0.2681 - accuracy: 0.8873
# Epoch 66/100
# 164/164 - 0s - loss: 0.2789 - accuracy: 0.8766
# Epoch 67/100
# 164/164 - 0s - loss: 0.2721 - accuracy: 0.8835
# Epoch 68/100
# 164/164 - 0s - loss: 0.2610 - accuracy: 0.8890
# Epoch 69/100
# 164/164 - 0s - loss: 0.2663 - accuracy: 0.8871
# Epoch 70/100
# 164/164 - 0s - loss: 0.2670 - accuracy: 0.8877
# Epoch 71/100
# 164/164 - 0s - loss: 0.2636 - accuracy: 0.8877
# Epoch 72/100
# 164/164 - 0s - loss: 0.2676 - accuracy: 0.8833
# Epoch 73/100
# 164/164 - 0s - loss: 0.2630 - accuracy: 0.8901
# Epoch 74/100
# 164/164 - 0s - loss: 0.2650 - accuracy: 0.8875
# Epoch 75/100
# 164/164 - 0s - loss: 0.2652 - accuracy: 0.8882
# Epoch 76/100
# 164/164 - 0s - loss: 0.2625 - accuracy: 0.8886
# Epoch 77/100
# 164/164 - 0s - loss: 0.2606 - accuracy: 0.8926
# Epoch 78/100
# 164/164 - 0s - loss: 0.2591 - accuracy: 0.8930
# Epoch 79/100
# 164/164 - 0s - loss: 0.2660 - accuracy: 0.8888
# Epoch 80/100
# 164/164 - 0s - loss: 0.2645 - accuracy: 0.8869
# Epoch 81/100
# 164/164 - 0s - loss: 0.2596 - accuracy: 0.8917
# Epoch 82/100
# 164/164 - 0s - loss: 0.2642 - accuracy: 0.8899
# Epoch 83/100
# 164/164 - 0s - loss: 0.2673 - accuracy: 0.8835
# Epoch 84/100
# 164/164 - 0s - loss: 0.2671 - accuracy: 0.8854
# Epoch 85/100
# 164/164 - 0s - loss: 0.2584 - accuracy: 0.8911
# Epoch 86/100
# 164/164 - 0s - loss: 0.2625 - accuracy: 0.8890
# Epoch 87/100
# 164/164 - 0s - loss: 0.2564 - accuracy: 0.8917
# Epoch 88/100
# 164/164 - 0s - loss: 0.2599 - accuracy: 0.8917
# Epoch 89/100
# 164/164 - 0s - loss: 0.2683 - accuracy: 0.8890
# Epoch 90/100
# 164/164 - 0s - loss: 0.2563 - accuracy: 0.8922
# Epoch 91/100
# 164/164 - 0s - loss: 0.2606 - accuracy: 0.8901
# Epoch 92/100
# 164/164 - 0s - loss: 0.2593 - accuracy: 0.8924
# Epoch 93/100
# 164/164 - 0s - loss: 0.2547 - accuracy: 0.8951
# Epoch 94/100
# 164/164 - 0s - loss: 0.2614 - accuracy: 0.8905
# Epoch 95/100
# 164/164 - 0s - loss: 0.2557 - accuracy: 0.8920
# Epoch 96/100
# 164/164 - 0s - loss: 0.2538 - accuracy: 0.8926
# Epoch 97/100
# 164/164 - 0s - loss: 0.2580 - accuracy: 0.8899
# Epoch 98/100
# 164/164 - 0s - loss: 0.2556 - accuracy: 0.8898
# Epoch 99/100
# 164/164 - 0s - loss: 0.2599 - accuracy: 0.8861
# Epoch 100/100
# 164/164 - 0s - loss: 0.2539 - accuracy: 0.8970

# %%
# scoring the model with more layers

deep_model2_loss, deep_model2_accuracy = deep_model2.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model2_loss}, Accuracy: {deep_model2_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2643 - accuracy: 0.8959
# Normal Neural Network - Loss: 0.2643410265445709, Accuracy: 0.8958809971809387

# %%
# Finding most important features

feat_model = RandomForestClassifier()
feat_model.fit(X_train_scaled, y_train_catagorical)
feats = feat_model.feature_importances_
feat_list = sorted(zip(feats,feature_names), reverse=True)
feat_list
# Out:
# [(0.10609241249936005, 'koi_fpflag_nt'),
#  (0.10490828383393712, 'koi_fpflag_co'),
#  (0.07239708426099763, 'koi_fpflag_ss'),
#  (0.053618395316294185, 'koi_prad'),
#  (0.052256945280473734, 'koi_model_snr'),
#  (0.040349159298171296, 'koi_duration_err2'),
#  (0.03522721436727802, 'koi_fpflag_ec'),
#  (0.034591183465736794, 'koi_duration_err1'),
#  (0.03265592411164437, 'koi_steff_err1'),
#  (0.03154042362046396, 'koi_prad_err2'),
#  (0.02425896131747935, 'koi_prad_err1'),
#  (0.02259951924316135, 'koi_steff_err2'),
#  (0.022265663734593964, 'koi_duration'),
#  (0.022214998514511888, 'koi_depth'),
#  (0.0213132689302937, 'koi_period'),
#  (0.020792771869247585, 'koi_insol_err1'),
#  (0.020656788233389886, 'koi_time0bk_err1'),
#  (0.019599388860085623, 'koi_impact'),
#  (0.0192262905932186, 'koi_time0bk_err2'),
#  (0.0176505973771433, 'koi_period_err2'),
#  (0.017628791439029377, 'koi_period_err1'),
#  (0.016183682397578572, 'koi_teq'),
#  (0.013929580749234182, 'koi_time0bk'),
#  (0.013882238460555052, 'koi_depth_err2'),
#  (0.013728226409192643, 'koi_depth_err1'),
#  (0.013067762498268106, 'koi_insol'),
#  (0.011854769167873046, 'ra'),
#  (0.011605325025172902, 'dec'),
#  (0.011396845188205988, 'koi_srad_err1'),
#  (0.011375077005083117, 'koi_slogg_err2'),
#  (0.011269508576257067, 'koi_impact_err2'),
#  (0.011221082609906294, 'koi_impact_err1'),
#  (0.010262722268435973, 'koi_kepmag'),
#  (0.010135684924624331, 'koi_insol_err2'),
#  (0.009857622327876054, 'koi_steff'),
#  (0.009158733861764074, 'koi_slogg'),
#  (0.009092822281807848, 'koi_srad'),
#  (0.008602277795565341, 'koi_srad_err2'),
#  (0.008453481859397743, 'koi_slogg_err1'),
#  (0.003078490426689875, 'koi_tce_plnt_num')]

# %%
# creating a selected features variable with only the top 15 most important variables!

short_feat_list = feat_list[:15]
short_feat_list = list(zip(*short_feat_list))
short_feat_list = list(short_feat_list[1])
tuned_X = df[short_feat_list]
tuned_X.shape
# Out:
# (6991, 15)

# %%
# creating a deep model with the most important variables

# Spliting the tuned data
tuned_X_train, tuned_X_test, y_train, y_test = train_test_split(tuned_X, target, random_state=42)

# Scaling the tuned data
tuned_X_scaler = MinMaxScaler().fit(tuned_X_train)

tuned_X_train_scaled = tuned_X_scaler.transform(tuned_X_train)
tuned_X_test_scaled = tuned_X_scaler.transform(tuned_X_test)

# Retraining the tuned data
tuned_deep_model = Sequential()
tuned_deep_model.add(Dense(units=10, activation='relu', input_dim=15))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=3, activation='softmax'))

# Compiling the tuned data
tuned_deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
tuned_deep_model.fit(tuned_X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.7332 - accuracy: 0.5987
# Epoch 2/100
# 164/164 - 0s - loss: 0.4089 - accuracy: 0.7486
# Epoch 3/100
# 164/164 - 0s - loss: 0.3906 - accuracy: 0.7562
# Epoch 4/100
# 164/164 - 0s - loss: 0.3858 - accuracy: 0.7862
# Epoch 5/100
# 164/164 - 0s - loss: 0.3786 - accuracy: 0.7961
# Epoch 6/100
# 164/164 - 0s - loss: 0.3638 - accuracy: 0.8230
# Epoch 7/100
# 164/164 - 0s - loss: 0.3565 - accuracy: 0.8261
# Epoch 8/100
# 164/164 - 0s - loss: 0.3500 - accuracy: 0.8291
# Epoch 9/100
# 164/164 - 0s - loss: 0.3491 - accuracy: 0.8297
# Epoch 10/100
# 164/164 - 0s - loss: 0.3475 - accuracy: 0.8308
# Epoch 11/100
# 164/164 - 0s - loss: 0.3390 - accuracy: 0.8392
# Epoch 12/100
# 164/164 - 0s - loss: 0.3296 - accuracy: 0.8472
# Epoch 13/100
# 164/164 - 0s - loss: 0.3328 - accuracy: 0.8428
# Epoch 14/100
# 164/164 - 0s - loss: 0.3258 - accuracy: 0.8486
# Epoch 15/100
# 164/164 - 0s - loss: 0.3173 - accuracy: 0.8554
# Epoch 16/100
# 164/164 - 0s - loss: 0.3151 - accuracy: 0.8566
# Epoch 17/100
# 164/164 - 0s - loss: 0.3117 - accuracy: 0.8573
# Epoch 18/100
# 164/164 - 0s - loss: 0.3102 - accuracy: 0.8600
# Epoch 19/100
# 164/164 - 0s - loss: 0.3030 - accuracy: 0.8674
# Epoch 20/100
# 164/164 - 0s - loss: 0.3055 - accuracy: 0.8644
# Epoch 21/100
# 164/164 - 0s - loss: 0.3029 - accuracy: 0.8665
# Epoch 22/100
# 164/164 - 0s - loss: 0.2987 - accuracy: 0.8648
# Epoch 23/100
# 164/164 - 0s - loss: 0.2998 - accuracy: 0.8663
# Epoch 24/100
# 164/164 - 0s - loss: 0.2974 - accuracy: 0.8680
# Epoch 25/100
# 164/164 - 0s - loss: 0.3007 - accuracy: 0.8667
# Epoch 26/100
# 164/164 - 0s - loss: 0.2935 - accuracy: 0.8688
# Epoch 27/100
# 164/164 - 0s - loss: 0.2945 - accuracy: 0.8747
# Epoch 28/100
# 164/164 - 0s - loss: 0.2943 - accuracy: 0.8701
# Epoch 29/100
# 164/164 - 0s - loss: 0.2874 - accuracy: 0.8781
# Epoch 30/100
# 164/164 - 0s - loss: 0.2931 - accuracy: 0.8720
# Epoch 31/100
# 164/164 - 0s - loss: 0.2947 - accuracy: 0.8722
# Epoch 32/100
# 164/164 - 0s - loss: 0.2869 - accuracy: 0.8787
# Epoch 33/100
# 164/164 - 0s - loss: 0.2844 - accuracy: 0.8774
# Epoch 34/100
# 164/164 - 0s - loss: 0.2862 - accuracy: 0.8768
# Epoch 35/100
# 164/164 - 0s - loss: 0.2858 - accuracy: 0.8756
# Epoch 36/100
# 164/164 - 0s - loss: 0.2866 - accuracy: 0.8774
# Epoch 37/100
# 164/164 - 0s - loss: 0.2864 - accuracy: 0.8753
# Epoch 38/100
# 164/164 - 0s - loss: 0.2848 - accuracy: 0.8753
# Epoch 39/100
# 164/164 - 0s - loss: 0.2875 - accuracy: 0.8737
# Epoch 40/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8770
# Epoch 41/100
# 164/164 - 0s - loss: 0.2870 - accuracy: 0.8743
# Epoch 42/100
# 164/164 - 0s - loss: 0.2826 - accuracy: 0.8796
# Epoch 43/100
# 164/164 - 0s - loss: 0.2830 - accuracy: 0.8774
# Epoch 44/100
# 164/164 - 0s - loss: 0.2806 - accuracy: 0.8783
# Epoch 45/100
# 164/164 - 0s - loss: 0.2798 - accuracy: 0.8783
# Epoch 46/100
# 164/164 - 0s - loss: 0.2806 - accuracy: 0.8787
# Epoch 47/100
# 164/164 - 0s - loss: 0.2861 - accuracy: 0.8724
# Epoch 48/100
# 164/164 - 0s - loss: 0.2859 - accuracy: 0.8745
# Epoch 49/100
# 164/164 - 0s - loss: 0.2793 - accuracy: 0.8789
# Epoch 50/100
# 164/164 - 0s - loss: 0.2804 - accuracy: 0.8751
# Epoch 51/100
# 164/164 - 0s - loss: 0.2783 - accuracy: 0.8798
# Epoch 52/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8804
# Epoch 53/100
# 164/164 - 0s - loss: 0.2802 - accuracy: 0.8785
# Epoch 54/100
# 164/164 - 0s - loss: 0.2811 - accuracy: 0.8737
# Epoch 55/100
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8751
# Epoch 56/100
# 164/164 - 0s - loss: 0.2737 - accuracy: 0.8838
# Epoch 57/100
# 164/164 - 0s - loss: 0.2787 - accuracy: 0.8783
# Epoch 58/100
# 164/164 - 0s - loss: 0.2862 - accuracy: 0.8753
# Epoch 59/100
# 164/164 - 0s - loss: 0.2771 - accuracy: 0.8772
# Epoch 60/100
# 164/164 - 0s - loss: 0.2758 - accuracy: 0.8770
# Epoch 61/100
# 164/164 - 0s - loss: 0.2737 - accuracy: 0.8835
# Epoch 62/100
# 164/164 - 0s - loss: 0.2759 - accuracy: 0.8800
# Epoch 63/100
# 164/164 - 0s - loss: 0.2805 - accuracy: 0.8756
# Epoch 64/100
# 164/164 - 0s - loss: 0.2840 - accuracy: 0.8745
# Epoch 65/100
# 164/164 - 0s - loss: 0.2752 - accuracy: 0.8825
# Epoch 66/100
# 164/164 - 0s - loss: 0.2779 - accuracy: 0.8779
# Epoch 67/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8783
# Epoch 68/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8787
# Epoch 69/100
# 164/164 - 0s - loss: 0.2753 - accuracy: 0.8808
# Epoch 70/100
# 164/164 - 0s - loss: 0.2736 - accuracy: 0.8814
# Epoch 71/100
# 164/164 - 0s - loss: 0.2730 - accuracy: 0.8806
# Epoch 72/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8793
# Epoch 73/100
# 164/164 - 0s - loss: 0.2745 - accuracy: 0.8791
# Epoch 74/100
# 164/164 - 0s - loss: 0.2763 - accuracy: 0.8789
# Epoch 75/100
# 164/164 - 0s - loss: 0.2795 - accuracy: 0.8728
# Epoch 76/100
# 164/164 - 0s - loss: 0.2742 - accuracy: 0.8829
# Epoch 77/100
# 164/164 - 0s - loss: 0.2754 - accuracy: 0.8772
# Epoch 78/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8758
# Epoch 79/100
# 164/164 - 0s - loss: 0.2780 - accuracy: 0.8777
# Epoch 80/100
# 164/164 - 0s - loss: 0.2732 - accuracy: 0.8785
# Epoch 81/100
# 164/164 - 0s - loss: 0.2739 - accuracy: 0.8810
# Epoch 82/100
# 164/164 - 0s - loss: 0.2710 - accuracy: 0.8819
# Epoch 83/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8791
# Epoch 84/100
# 164/164 - 0s - loss: 0.2758 - accuracy: 0.8787
# Epoch 85/100
# 164/164 - 0s - loss: 0.2702 - accuracy: 0.8804
# Epoch 86/100
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8858
# Epoch 87/100
# 164/164 - 0s - loss: 0.2676 - accuracy: 0.8842
# Epoch 88/100
# 164/164 - 0s - loss: 0.2700 - accuracy: 0.8816
# Epoch 89/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8806
# Epoch 90/100
# 164/164 - 0s - loss: 0.2726 - accuracy: 0.8817
# Epoch 91/100
# 164/164 - 0s - loss: 0.2713 - accuracy: 0.8804
# Epoch 92/100
# 164/164 - 0s - loss: 0.2687 - accuracy: 0.8808
# Epoch 93/100
# 164/164 - 0s - loss: 0.2714 - accuracy: 0.8816
# Epoch 94/100
# 164/164 - 0s - loss: 0.2694 - accuracy: 0.8854
# Epoch 95/100
# 164/164 - 0s - loss: 0.2710 - accuracy: 0.8798
# Epoch 96/100
# 164/164 - 0s - loss: 0.2734 - accuracy: 0.8833
# Epoch 97/100
# 164/164 - 0s - loss: 0.2693 - accuracy: 0.8823
# Epoch 98/100
# 164/164 - 0s - loss: 0.2713 - accuracy: 0.8827
# Epoch 99/100
# 164/164 - 0s - loss: 0.2712 - accuracy: 0.8781
# Epoch 100/100
# 164/164 - 0s - loss: 0.2642 - accuracy: 0.8873

# %%
# Scoring the tuned data
tuned_deep_model_loss, tuned_deep_model_accuracy = tuned_deep_model.evaluate(tuned_X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {tuned_deep_model_loss}, Accuracy: {tuned_deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2682 - accuracy: 0.8913
# Normal Neural Network - Loss: 0.26819220185279846, Accuracy: 0.8913043737411499

# %%
# Compare the diffent models

print(f'deep_model accuracy: {deep_model_accuracy}')
print(f'deep_model2 accuracy: {deep_model2_accuracy}')
print(f'tuned_deep_model accuracy: {tuned_deep_model_accuracy}')

model_list = ['deep_model', 'deep_model2', 'tuned_deep_model']
accuracy_list = [deep_model_accuracy ,deep_model2_accuracy, tuned_deep_model_accuracy]

summary_df = pd.DataFrame({'Model Name': model_list, 'Model Accuracy': accuracy_list})
summary_df
# Out:
# deep_model accuracy: 0.8678489923477173
# deep_model2 accuracy: 0.8958809971809387
# tuned_deep_model accuracy: 0.8913043737411499
#          Model Name  Model Accuracy
# 0        deep_model        0.867849
# 1       deep_model2        0.895881
# 2  tuned_deep_model        0.891304

# %%
# choosing model with highest accuracy
best_model = summary_df.max()
best_model
# Out:
# Model Name        tuned_deep_model
# Model Accuracy            0.895881
# dtype: object

# %%
# Saving that model

best_model_name = best_model['Model Name']
best_model_name
# Out:
# 'tuned_deep_model'

# %%
# Saving the model
tuned_deep_model.save('Models/Neural_Newtork_Model.h5')
