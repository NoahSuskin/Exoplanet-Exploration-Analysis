# %%
from numpy.random import seed
seed(1)
import pandas as pd
import tensorflow
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# %%
# loading data into a dataframe

file_path = '../Resources/exoplanet_data.csv'

df = pd.read_csv(file_path)
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
# Setting features and target
target = df['koi_disposition']
selected_features = df.drop(['koi_disposition'], axis=1)

# Selected Feature Names
feature_names = selected_features.columns.tolist()

# looking at the shape of the variables
print(target.shape, selected_features.shape)
# Out:
# (6991,) (6991, 40)

# %%
# Splitting the data into a training set and testing set and scaling

X_train, X_test, y_train, y_test = train_test_split(selected_features, target, random_state=42)

X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# Encoding the target variable
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)

# Converting the encoded target variable into a catagorical form
y_train_catagorical = to_categorical(encoded_y_train)
y_test_catagorical = to_categorical(encoded_y_test)

# %%
# Creating the deep model

deep_model = Sequential()
deep_model.add(Dense(units=100, activation='relu', input_dim=40))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model

deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.5582 - accuracy: 0.7120
# Epoch 2/100
# 164/164 - 0s - loss: 0.3673 - accuracy: 0.8053
# Epoch 3/100
# 164/164 - 0s - loss: 0.3491 - accuracy: 0.8198
# Epoch 4/100
# 164/164 - 0s - loss: 0.3390 - accuracy: 0.8323
# Epoch 5/100
# 164/164 - 0s - loss: 0.3281 - accuracy: 0.8381
# Epoch 6/100
# 164/164 - 0s - loss: 0.3191 - accuracy: 0.8478
# Epoch 7/100
# 164/164 - 0s - loss: 0.3141 - accuracy: 0.8526
# Epoch 8/100
# 164/164 - 0s - loss: 0.3109 - accuracy: 0.8556
# Epoch 9/100
# 164/164 - 0s - loss: 0.3104 - accuracy: 0.8528
# Epoch 10/100
# 164/164 - 0s - loss: 0.3043 - accuracy: 0.8627
# Epoch 11/100
# 164/164 - 0s - loss: 0.3015 - accuracy: 0.8608
# Epoch 12/100
# 164/164 - 0s - loss: 0.3009 - accuracy: 0.8621
# Epoch 13/100
# 164/164 - 0s - loss: 0.2962 - accuracy: 0.8667
# Epoch 14/100
# 164/164 - 0s - loss: 0.2953 - accuracy: 0.8680
# Epoch 15/100
# 164/164 - 0s - loss: 0.2967 - accuracy: 0.8663
# Epoch 16/100
# 164/164 - 0s - loss: 0.2872 - accuracy: 0.8695
# Epoch 17/100
# 164/164 - 0s - loss: 0.2847 - accuracy: 0.8756
# Epoch 18/100
# 164/164 - 0s - loss: 0.2859 - accuracy: 0.8762
# Epoch 19/100
# 164/164 - 0s - loss: 0.2825 - accuracy: 0.8737
# Epoch 20/100
# 164/164 - 0s - loss: 0.2870 - accuracy: 0.8709
# Epoch 21/100
# 164/164 - 0s - loss: 0.2820 - accuracy: 0.8777
# Epoch 22/100
# 164/164 - 0s - loss: 0.2790 - accuracy: 0.8779
# Epoch 23/100
# 164/164 - 0s - loss: 0.2758 - accuracy: 0.8785
# Epoch 24/100
# 164/164 - 0s - loss: 0.2785 - accuracy: 0.8821
# Epoch 25/100
# 164/164 - 0s - loss: 0.2784 - accuracy: 0.8764
# Epoch 26/100
# 164/164 - 0s - loss: 0.2724 - accuracy: 0.8817
# Epoch 27/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8800
# Epoch 28/100
# 164/164 - 0s - loss: 0.2677 - accuracy: 0.8840
# Epoch 29/100
# 164/164 - 0s - loss: 0.2743 - accuracy: 0.8753
# Epoch 30/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8844
# Epoch 31/100
# 164/164 - 0s - loss: 0.2634 - accuracy: 0.8873
# Epoch 32/100
# 164/164 - 0s - loss: 0.2684 - accuracy: 0.8802
# Epoch 33/100
# 164/164 - 0s - loss: 0.2659 - accuracy: 0.8880
# Epoch 34/100
# 164/164 - 0s - loss: 0.2608 - accuracy: 0.8859
# Epoch 35/100
# 164/164 - 0s - loss: 0.2610 - accuracy: 0.8859
# Epoch 36/100
# 164/164 - 0s - loss: 0.2634 - accuracy: 0.8823
# Epoch 37/100
# 164/164 - 0s - loss: 0.2636 - accuracy: 0.8817
# Epoch 38/100
# 164/164 - 0s - loss: 0.2665 - accuracy: 0.8817
# Epoch 39/100
# 164/164 - 0s - loss: 0.2613 - accuracy: 0.8861
# Epoch 40/100
# 164/164 - 0s - loss: 0.2543 - accuracy: 0.8905
# Epoch 41/100
# 164/164 - 0s - loss: 0.2531 - accuracy: 0.8873
# Epoch 42/100
# 164/164 - 0s - loss: 0.2563 - accuracy: 0.8907
# Epoch 43/100
# 164/164 - 0s - loss: 0.2537 - accuracy: 0.8899
# Epoch 44/100
# 164/164 - 0s - loss: 0.2480 - accuracy: 0.8926
# Epoch 45/100
# 164/164 - 0s - loss: 0.2503 - accuracy: 0.8907
# Epoch 46/100
# 164/164 - 0s - loss: 0.2529 - accuracy: 0.8903
# Epoch 47/100
# 164/164 - 0s - loss: 0.2448 - accuracy: 0.8947
# Epoch 48/100
# 164/164 - 0s - loss: 0.2477 - accuracy: 0.8930
# Epoch 49/100
# 164/164 - 0s - loss: 0.2454 - accuracy: 0.8913
# Epoch 50/100
# 164/164 - 0s - loss: 0.2444 - accuracy: 0.8909
# Epoch 51/100
# 164/164 - 0s - loss: 0.2510 - accuracy: 0.8877
# Epoch 52/100
# 164/164 - 0s - loss: 0.2481 - accuracy: 0.8915
# Epoch 53/100
# 164/164 - 0s - loss: 0.2432 - accuracy: 0.8949
# Epoch 54/100
# 164/164 - 0s - loss: 0.2460 - accuracy: 0.8901
# Epoch 55/100
# 164/164 - 0s - loss: 0.2412 - accuracy: 0.8959
# Epoch 56/100
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8924
# Epoch 57/100
# 164/164 - 0s - loss: 0.2392 - accuracy: 0.8953
# Epoch 58/100
# 164/164 - 0s - loss: 0.2388 - accuracy: 0.8949
# Epoch 59/100
# 164/164 - 0s - loss: 0.2433 - accuracy: 0.8920
# Epoch 60/100
# 164/164 - 0s - loss: 0.2345 - accuracy: 0.9004
# Epoch 61/100
# 164/164 - 0s - loss: 0.2339 - accuracy: 0.8970
# Epoch 62/100
# 164/164 - 0s - loss: 0.2327 - accuracy: 0.8987
# Epoch 63/100
# 164/164 - 0s - loss: 0.2332 - accuracy: 0.8959
# Epoch 64/100
# 164/164 - 0s - loss: 0.2368 - accuracy: 0.8941
# Epoch 65/100
# 164/164 - 0s - loss: 0.2363 - accuracy: 0.8940
# Epoch 66/100
# 164/164 - 0s - loss: 0.2331 - accuracy: 0.8949
# Epoch 67/100
# 164/164 - 0s - loss: 0.2400 - accuracy: 0.8865
# Epoch 68/100
# 164/164 - 0s - loss: 0.2320 - accuracy: 0.8966
# Epoch 69/100
# 164/164 - 0s - loss: 0.2343 - accuracy: 0.8932
# Epoch 70/100
# 164/164 - 0s - loss: 0.2348 - accuracy: 0.8930
# Epoch 71/100
# 164/164 - 0s - loss: 0.2292 - accuracy: 0.9010
# Epoch 72/100
# 164/164 - 0s - loss: 0.2281 - accuracy: 0.9012
# Epoch 73/100
# 164/164 - 0s - loss: 0.2275 - accuracy: 0.8974
# Epoch 74/100
# 164/164 - 0s - loss: 0.2283 - accuracy: 0.8993
# Epoch 75/100
# 164/164 - 0s - loss: 0.2274 - accuracy: 0.9029
# Epoch 76/100
# 164/164 - 0s - loss: 0.2291 - accuracy: 0.8993
# Epoch 77/100
# 164/164 - 0s - loss: 0.2280 - accuracy: 0.8987
# Epoch 78/100
# 164/164 - 0s - loss: 0.2285 - accuracy: 0.9001
# Epoch 79/100
# 164/164 - 0s - loss: 0.2364 - accuracy: 0.8913
# Epoch 80/100
# 164/164 - 0s - loss: 0.2252 - accuracy: 0.9001
# Epoch 81/100
# 164/164 - 0s - loss: 0.2241 - accuracy: 0.9004
# Epoch 82/100
# 164/164 - 0s - loss: 0.2270 - accuracy: 0.8961
# Epoch 83/100
# 164/164 - 0s - loss: 0.2242 - accuracy: 0.9029
# Epoch 84/100
# 164/164 - 0s - loss: 0.2254 - accuracy: 0.8997
# Epoch 85/100
# 164/164 - 0s - loss: 0.2242 - accuracy: 0.9029
# Epoch 86/100
# 164/164 - 0s - loss: 0.2232 - accuracy: 0.9014
# Epoch 87/100
# 164/164 - 0s - loss: 0.2260 - accuracy: 0.9010
# Epoch 88/100
# 164/164 - 0s - loss: 0.2193 - accuracy: 0.9020
# Epoch 89/100
# 164/164 - 0s - loss: 0.2231 - accuracy: 0.9001
# Epoch 90/100
# 164/164 - 0s - loss: 0.2187 - accuracy: 0.9020
# Epoch 91/100
# 164/164 - 0s - loss: 0.2242 - accuracy: 0.8989
# Epoch 92/100
# 164/164 - 0s - loss: 0.2208 - accuracy: 0.9004
# Epoch 93/100
# 164/164 - 0s - loss: 0.2174 - accuracy: 0.9039
# Epoch 94/100
# 164/164 - 0s - loss: 0.2194 - accuracy: 0.9016
# Epoch 95/100
# 164/164 - 0s - loss: 0.2201 - accuracy: 0.9006
# Epoch 96/100
# 164/164 - 0s - loss: 0.2147 - accuracy: 0.9018
# Epoch 97/100
# 164/164 - 0s - loss: 0.2178 - accuracy: 0.9044
# Epoch 98/100
# 164/164 - 0s - loss: 0.2145 - accuracy: 0.9075
# Epoch 99/100
# 164/164 - 0s - loss: 0.2120 - accuracy: 0.9048
# Epoch 100/100
# 164/164 - 0s - loss: 0.2147 - accuracy: 0.9041

# %%
# scoring the model

deep_model_loss, deep_model_accuracy = deep_model.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model_loss}, Accuracy: {deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2747 - accuracy: 0.8919
# Normal Neural Network - Loss: 0.27470627427101135, Accuracy: 0.8918764591217041

# %%
# Creating a model with more neural layers

deep_model2 = Sequential()
deep_model2.add(Dense(units=100, activation='relu', input_dim=40))
deep_model2.add(Dense(units=100, activation='relu'))
deep_model2.add(Dense(units=100, activation='relu'))
deep_model2.add(Dense(units=100, activation='relu'))
deep_model2.add(Dense(units=100, activation='relu'))
deep_model2.add(Dense(units=3, activation='softmax'))

# %%
# Compiling the model with more layers

deep_model2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
deep_model2.fit(X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.4944 - accuracy: 0.7322
# Epoch 2/100
# 164/164 - 0s - loss: 0.3824 - accuracy: 0.7902
# Epoch 3/100
# 164/164 - 0s - loss: 0.3705 - accuracy: 0.8051
# Epoch 4/100
# 164/164 - 0s - loss: 0.3507 - accuracy: 0.8173
# Epoch 5/100
# 164/164 - 0s - loss: 0.3399 - accuracy: 0.8337
# Epoch 6/100
# 164/164 - 0s - loss: 0.3463 - accuracy: 0.8253
# Epoch 7/100
# 164/164 - 0s - loss: 0.3269 - accuracy: 0.8507
# Epoch 8/100
# 164/164 - 0s - loss: 0.3320 - accuracy: 0.8356
# Epoch 9/100
# 164/164 - 0s - loss: 0.3214 - accuracy: 0.8468
# Epoch 10/100
# 164/164 - 0s - loss: 0.3177 - accuracy: 0.8529
# Epoch 11/100
# 164/164 - 0s - loss: 0.3093 - accuracy: 0.8592
# Epoch 12/100
# 164/164 - 0s - loss: 0.3080 - accuracy: 0.8594
# Epoch 13/100
# 164/164 - 0s - loss: 0.3181 - accuracy: 0.8554
# Epoch 14/100
# 164/164 - 0s - loss: 0.3025 - accuracy: 0.8642
# Epoch 15/100
# 164/164 - 0s - loss: 0.3015 - accuracy: 0.8661
# Epoch 16/100
# 164/164 - 0s - loss: 0.3036 - accuracy: 0.8613
# Epoch 17/100
# 164/164 - 0s - loss: 0.2885 - accuracy: 0.8718
# Epoch 18/100
# 164/164 - 0s - loss: 0.2903 - accuracy: 0.8713
# Epoch 19/100
# 164/164 - 0s - loss: 0.2782 - accuracy: 0.8798
# Epoch 20/100
# 164/164 - 0s - loss: 0.2776 - accuracy: 0.8789
# Epoch 21/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8800
# Epoch 22/100
# 164/164 - 0s - loss: 0.2731 - accuracy: 0.8802
# Epoch 23/100
# 164/164 - 0s - loss: 0.2715 - accuracy: 0.8798
# Epoch 24/100
# 164/164 - 0s - loss: 0.2739 - accuracy: 0.8779
# Epoch 25/100
# 164/164 - 0s - loss: 0.2707 - accuracy: 0.8827
# Epoch 26/100
# 164/164 - 0s - loss: 0.2770 - accuracy: 0.8793
# Epoch 27/100
# 164/164 - 0s - loss: 0.2669 - accuracy: 0.8819
# Epoch 28/100
# 164/164 - 0s - loss: 0.2658 - accuracy: 0.8837
# Epoch 29/100
# 164/164 - 0s - loss: 0.2525 - accuracy: 0.8917
# Epoch 30/100
# 164/164 - 0s - loss: 0.2676 - accuracy: 0.8846
# Epoch 31/100
# 164/164 - 0s - loss: 0.2668 - accuracy: 0.8821
# Epoch 32/100
# 164/164 - 0s - loss: 0.2705 - accuracy: 0.8795
# Epoch 33/100
# 164/164 - 0s - loss: 0.2657 - accuracy: 0.8814
# Epoch 34/100
# 164/164 - 0s - loss: 0.2573 - accuracy: 0.8894
# Epoch 35/100
# 164/164 - 0s - loss: 0.2550 - accuracy: 0.8882
# Epoch 36/100
# 164/164 - 0s - loss: 0.2533 - accuracy: 0.8884
# Epoch 37/100
# 164/164 - 0s - loss: 0.2505 - accuracy: 0.8877
# Epoch 38/100
# 164/164 - 0s - loss: 0.2483 - accuracy: 0.8890
# Epoch 39/100
# 164/164 - 0s - loss: 0.2461 - accuracy: 0.8926
# Epoch 40/100
# 164/164 - 0s - loss: 0.2649 - accuracy: 0.8800
# Epoch 41/100
# 164/164 - 0s - loss: 0.2447 - accuracy: 0.8917
# Epoch 42/100
# 164/164 - 0s - loss: 0.2493 - accuracy: 0.8896
# Epoch 43/100
# 164/164 - 0s - loss: 0.2487 - accuracy: 0.8882
# Epoch 44/100
# 164/164 - 0s - loss: 0.2446 - accuracy: 0.8947
# Epoch 45/100
# 164/164 - 0s - loss: 0.2625 - accuracy: 0.8837
# Epoch 46/100
# 164/164 - 0s - loss: 0.2430 - accuracy: 0.8922
# Epoch 47/100
# 164/164 - 0s - loss: 0.2430 - accuracy: 0.8932
# Epoch 48/100
# 164/164 - 0s - loss: 0.2418 - accuracy: 0.8924
# Epoch 49/100
# 164/164 - 0s - loss: 0.2406 - accuracy: 0.8947
# Epoch 50/100
# 164/164 - 0s - loss: 0.2359 - accuracy: 0.8941
# Epoch 51/100
# 164/164 - 0s - loss: 0.2381 - accuracy: 0.8945
# Epoch 52/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8936
# Epoch 53/100
# 164/164 - 0s - loss: 0.2374 - accuracy: 0.8922
# Epoch 54/100
# 164/164 - 0s - loss: 0.2346 - accuracy: 0.8966
# Epoch 55/100
# 164/164 - 0s - loss: 0.2322 - accuracy: 0.8987
# Epoch 56/100
# 164/164 - 0s - loss: 0.2308 - accuracy: 0.8978
# Epoch 57/100
# 164/164 - 0s - loss: 0.2384 - accuracy: 0.8924
# Epoch 58/100
# 164/164 - 0s - loss: 0.2252 - accuracy: 0.9008
# Epoch 59/100
# 164/164 - 0s - loss: 0.2309 - accuracy: 0.8957
# Epoch 60/100
# 164/164 - 0s - loss: 0.2298 - accuracy: 0.8957
# Epoch 61/100
# 164/164 - 0s - loss: 0.2428 - accuracy: 0.8941
# Epoch 62/100
# 164/164 - 0s - loss: 0.2364 - accuracy: 0.8961
# Epoch 63/100
# 164/164 - 0s - loss: 0.2290 - accuracy: 0.8945
# Epoch 64/100
# 164/164 - 0s - loss: 0.2290 - accuracy: 0.8959
# Epoch 65/100
# 164/164 - 0s - loss: 0.2289 - accuracy: 0.8936
# Epoch 66/100
# 164/164 - 0s - loss: 0.2241 - accuracy: 0.9010
# Epoch 67/100
# 164/164 - 0s - loss: 0.2306 - accuracy: 0.8985
# Epoch 68/100
# 164/164 - 0s - loss: 0.2225 - accuracy: 0.9014
# Epoch 69/100
# 164/164 - 0s - loss: 0.2246 - accuracy: 0.8989
# Epoch 70/100
# 164/164 - 0s - loss: 0.2197 - accuracy: 0.9033
# Epoch 71/100
# 164/164 - 0s - loss: 0.2347 - accuracy: 0.8955
# Epoch 72/100
# 164/164 - 0s - loss: 0.2245 - accuracy: 0.9004
# Epoch 73/100
# 164/164 - 0s - loss: 0.2192 - accuracy: 0.9037
# Epoch 74/100
# 164/164 - 0s - loss: 0.2244 - accuracy: 0.8976
# Epoch 75/100
# 164/164 - 0s - loss: 0.2218 - accuracy: 0.9012
# Epoch 76/100
# 164/164 - 0s - loss: 0.2224 - accuracy: 0.8999
# Epoch 77/100
# 164/164 - 0s - loss: 0.2231 - accuracy: 0.9018
# Epoch 78/100
# 164/164 - 0s - loss: 0.2220 - accuracy: 0.9001
# Epoch 79/100
# 164/164 - 0s - loss: 0.2173 - accuracy: 0.9027
# Epoch 80/100
# 164/164 - 0s - loss: 0.2166 - accuracy: 0.9052
# Epoch 81/100
# 164/164 - 0s - loss: 0.2180 - accuracy: 0.8995
# Epoch 82/100
# 164/164 - 0s - loss: 0.2184 - accuracy: 0.9004
# Epoch 83/100
# 164/164 - 0s - loss: 0.2175 - accuracy: 0.9031
# Epoch 84/100
# 164/164 - 0s - loss: 0.2134 - accuracy: 0.9023
# Epoch 85/100
# 164/164 - 0s - loss: 0.2156 - accuracy: 0.9018
# Epoch 86/100
# 164/164 - 0s - loss: 0.2096 - accuracy: 0.9071
# Epoch 87/100
# 164/164 - 0s - loss: 0.2125 - accuracy: 0.9031
# Epoch 88/100
# 164/164 - 0s - loss: 0.2436 - accuracy: 0.8964
# Epoch 89/100
# 164/164 - 0s - loss: 0.2126 - accuracy: 0.9025
# Epoch 90/100
# 164/164 - 0s - loss: 0.2147 - accuracy: 0.8995
# Epoch 91/100
# 164/164 - 0s - loss: 0.2113 - accuracy: 0.9012
# Epoch 92/100
# 164/164 - 0s - loss: 0.2131 - accuracy: 0.9016
# Epoch 93/100
# 164/164 - 0s - loss: 0.2162 - accuracy: 0.9027
# Epoch 94/100
# 164/164 - 0s - loss: 0.2113 - accuracy: 0.9069
# Epoch 95/100
# 164/164 - 0s - loss: 0.2054 - accuracy: 0.9107
# Epoch 96/100
# 164/164 - 0s - loss: 0.2221 - accuracy: 0.8983
# Epoch 97/100
# 164/164 - 0s - loss: 0.2087 - accuracy: 0.9069
# Epoch 98/100
# 164/164 - 0s - loss: 0.2084 - accuracy: 0.9071
# Epoch 99/100
# 164/164 - 0s - loss: 0.2019 - accuracy: 0.9077
# Epoch 100/100
# 164/164 - 0s - loss: 0.1988 - accuracy: 0.9096

# %%
# scoring the model with more layers

deep_model2_loss, deep_model2_accuracy = deep_model2.evaluate(X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {deep_model2_loss}, Accuracy: {deep_model2_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.3372 - accuracy: 0.8884
# Normal Neural Network - Loss: 0.3371689021587372, Accuracy: 0.8884439468383789

# %%
# Finding most important features

feat_model = RandomForestClassifier()
feat_model.fit(X_train_scaled, y_train_catagorical)
feats = feat_model.feature_importances_
feat_list = sorted(zip(feats,feature_names), reverse=True)
feat_list
# Out:
# [(0.10609241249936005, 'koi_fpflag_nt'),
#  (0.10490828383393712, 'koi_fpflag_co'),
#  (0.07239708426099763, 'koi_fpflag_ss'),
#  (0.053618395316294185, 'koi_prad'),
#  (0.052256945280473734, 'koi_model_snr'),
#  (0.040349159298171296, 'koi_duration_err2'),
#  (0.03522721436727802, 'koi_fpflag_ec'),
#  (0.034591183465736794, 'koi_duration_err1'),
#  (0.03265592411164437, 'koi_steff_err1'),
#  (0.03154042362046396, 'koi_prad_err2'),
#  (0.02425896131747935, 'koi_prad_err1'),
#  (0.02259951924316135, 'koi_steff_err2'),
#  (0.022265663734593964, 'koi_duration'),
#  (0.022214998514511888, 'koi_depth'),
#  (0.0213132689302937, 'koi_period'),
#  (0.020792771869247585, 'koi_insol_err1'),
#  (0.020656788233389886, 'koi_time0bk_err1'),
#  (0.019599388860085623, 'koi_impact'),
#  (0.0192262905932186, 'koi_time0bk_err2'),
#  (0.0176505973771433, 'koi_period_err2'),
#  (0.017628791439029377, 'koi_period_err1'),
#  (0.016183682397578572, 'koi_teq'),
#  (0.013929580749234182, 'koi_time0bk'),
#  (0.013882238460555052, 'koi_depth_err2'),
#  (0.013728226409192643, 'koi_depth_err1'),
#  (0.013067762498268106, 'koi_insol'),
#  (0.011854769167873046, 'ra'),
#  (0.011605325025172902, 'dec'),
#  (0.011396845188205988, 'koi_srad_err1'),
#  (0.011375077005083117, 'koi_slogg_err2'),
#  (0.011269508576257067, 'koi_impact_err2'),
#  (0.011221082609906294, 'koi_impact_err1'),
#  (0.010262722268435973, 'koi_kepmag'),
#  (0.010135684924624331, 'koi_insol_err2'),
#  (0.009857622327876054, 'koi_steff'),
#  (0.009158733861764074, 'koi_slogg'),
#  (0.009092822281807848, 'koi_srad'),
#  (0.008602277795565341, 'koi_srad_err2'),
#  (0.008453481859397743, 'koi_slogg_err1'),
#  (0.003078490426689875, 'koi_tce_plnt_num')]

# %%
# creating a selected features variable with only the top 15 most important variables!

short_feat_list = feat_list[:15]
short_feat_list = list(zip(*short_feat_list))
short_feat_list = list(short_feat_list[1])
tuned_X = df[short_feat_list]
tuned_X.shape
# Out:
# (6991, 15)

# %%
# creating a deep model with the most important variables

# Spliting the tuned data
tuned_X_train, tuned_X_test, y_train, y_test = train_test_split(tuned_X, target, random_state=42)

# Scaling the tuned data
tuned_X_scaler = MinMaxScaler().fit(tuned_X_train)

tuned_X_train_scaled = tuned_X_scaler.transform(tuned_X_train)
tuned_X_test_scaled = tuned_X_scaler.transform(tuned_X_test)

# Retraining the tuned data
tuned_deep_model = Sequential()
tuned_deep_model.add(Dense(units=10, activation='relu', input_dim=15))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=10, activation='relu'))
tuned_deep_model.add(Dense(units=3, activation='softmax'))

# Compiling the tuned data
tuned_deep_model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
tuned_deep_model.fit(tuned_X_train_scaled, y_train_catagorical, epochs=100, shuffle=True, verbose=2)
# Out:
# Epoch 1/100
# 164/164 - 0s - loss: 0.7651 - accuracy: 0.5718
# Epoch 2/100
# 164/164 - 0s - loss: 0.5074 - accuracy: 0.7448
# Epoch 3/100
# 164/164 - 0s - loss: 0.4012 - accuracy: 0.7454
# Epoch 4/100
# 164/164 - 0s - loss: 0.3909 - accuracy: 0.7444
# Epoch 5/100
# 164/164 - 0s - loss: 0.3894 - accuracy: 0.7412
# Epoch 6/100
# 164/164 - 0s - loss: 0.3889 - accuracy: 0.7492
# Epoch 7/100
# 164/164 - 0s - loss: 0.3886 - accuracy: 0.7572
# Epoch 8/100
# 164/164 - 0s - loss: 0.3863 - accuracy: 0.7654
# Epoch 9/100
# 164/164 - 0s - loss: 0.3815 - accuracy: 0.7831
# Epoch 10/100
# 164/164 - 0s - loss: 0.3720 - accuracy: 0.8026
# Epoch 11/100
# 164/164 - 0s - loss: 0.3674 - accuracy: 0.8137
# Epoch 12/100
# 164/164 - 0s - loss: 0.3591 - accuracy: 0.8217
# Epoch 13/100
# 164/164 - 0s - loss: 0.3574 - accuracy: 0.8213
# Epoch 14/100
# 164/164 - 0s - loss: 0.3560 - accuracy: 0.8262
# Epoch 15/100
# 164/164 - 0s - loss: 0.3509 - accuracy: 0.8291
# Epoch 16/100
# 164/164 - 0s - loss: 0.3506 - accuracy: 0.8270
# Epoch 17/100
# 164/164 - 0s - loss: 0.3488 - accuracy: 0.8291
# Epoch 18/100
# 164/164 - 0s - loss: 0.3448 - accuracy: 0.8310
# Epoch 19/100
# 164/164 - 0s - loss: 0.3457 - accuracy: 0.8301
# Epoch 20/100
# 164/164 - 0s - loss: 0.3431 - accuracy: 0.8333
# Epoch 21/100
# 164/164 - 0s - loss: 0.3433 - accuracy: 0.8304
# Epoch 22/100
# 164/164 - 0s - loss: 0.3397 - accuracy: 0.8373
# Epoch 23/100
# 164/164 - 0s - loss: 0.3378 - accuracy: 0.8346
# Epoch 24/100
# 164/164 - 0s - loss: 0.3360 - accuracy: 0.8404
# Epoch 25/100
# 164/164 - 0s - loss: 0.3368 - accuracy: 0.8386
# Epoch 26/100
# 164/164 - 0s - loss: 0.3341 - accuracy: 0.8398
# Epoch 27/100
# 164/164 - 0s - loss: 0.3315 - accuracy: 0.8440
# Epoch 28/100
# 164/164 - 0s - loss: 0.3295 - accuracy: 0.8451
# Epoch 29/100
# 164/164 - 0s - loss: 0.3304 - accuracy: 0.8461
# Epoch 30/100
# 164/164 - 0s - loss: 0.3252 - accuracy: 0.8510
# Epoch 31/100
# 164/164 - 0s - loss: 0.3217 - accuracy: 0.8505
# Epoch 32/100
# 164/164 - 0s - loss: 0.3202 - accuracy: 0.8512
# Epoch 33/100
# 164/164 - 0s - loss: 0.3195 - accuracy: 0.8507
# Epoch 34/100
# 164/164 - 0s - loss: 0.3162 - accuracy: 0.8564
# Epoch 35/100
# 164/164 - 0s - loss: 0.3162 - accuracy: 0.8533
# Epoch 36/100
# 164/164 - 0s - loss: 0.3072 - accuracy: 0.8581
# Epoch 37/100
# 164/164 - 0s - loss: 0.3063 - accuracy: 0.8640
# Epoch 38/100
# 164/164 - 0s - loss: 0.3070 - accuracy: 0.8587
# Epoch 39/100
# 164/164 - 0s - loss: 0.3078 - accuracy: 0.8581
# Epoch 40/100
# 164/164 - 0s - loss: 0.3034 - accuracy: 0.8629
# Epoch 41/100
# 164/164 - 0s - loss: 0.2935 - accuracy: 0.8682
# Epoch 42/100
# 164/164 - 0s - loss: 0.3018 - accuracy: 0.8619
# Epoch 43/100
# 164/164 - 0s - loss: 0.2907 - accuracy: 0.8722
# Epoch 44/100
# 164/164 - 0s - loss: 0.2903 - accuracy: 0.8756
# Epoch 45/100
# 164/164 - 0s - loss: 0.2876 - accuracy: 0.8758
# Epoch 46/100
# 164/164 - 0s - loss: 0.2935 - accuracy: 0.8732
# Epoch 47/100
# 164/164 - 0s - loss: 0.2857 - accuracy: 0.8726
# Epoch 48/100
# 164/164 - 0s - loss: 0.2851 - accuracy: 0.8747
# Epoch 49/100
# 164/164 - 0s - loss: 0.2895 - accuracy: 0.8732
# Epoch 50/100
# 164/164 - 0s - loss: 0.2843 - accuracy: 0.8747
# Epoch 51/100
# 164/164 - 0s - loss: 0.2799 - accuracy: 0.8798
# Epoch 52/100
# 164/164 - 0s - loss: 0.2874 - accuracy: 0.8703
# Epoch 53/100
# 164/164 - 0s - loss: 0.2835 - accuracy: 0.8766
# Epoch 54/100
# 164/164 - 0s - loss: 0.2792 - accuracy: 0.8817
# Epoch 55/100
# 164/164 - 0s - loss: 0.2804 - accuracy: 0.8787
# Epoch 56/100
# 164/164 - 0s - loss: 0.2792 - accuracy: 0.8776
# Epoch 57/100
# 164/164 - 0s - loss: 0.2865 - accuracy: 0.8732
# Epoch 58/100
# 164/164 - 0s - loss: 0.2762 - accuracy: 0.8802
# Epoch 59/100
# 164/164 - 0s - loss: 0.2747 - accuracy: 0.8825
# Epoch 60/100
# 164/164 - 0s - loss: 0.2757 - accuracy: 0.8787
# Epoch 61/100
# 164/164 - 0s - loss: 0.2719 - accuracy: 0.8842
# Epoch 62/100
# 164/164 - 0s - loss: 0.2741 - accuracy: 0.8808
# Epoch 63/100
# 164/164 - 0s - loss: 0.2726 - accuracy: 0.8821
# Epoch 64/100
# 164/164 - 0s - loss: 0.2752 - accuracy: 0.8831
# Epoch 65/100
# 164/164 - 0s - loss: 0.2806 - accuracy: 0.8760
# Epoch 66/100
# 164/164 - 0s - loss: 0.2698 - accuracy: 0.8858
# Epoch 67/100
# 164/164 - 0s - loss: 0.2762 - accuracy: 0.8831
# Epoch 68/100
# 164/164 - 0s - loss: 0.2873 - accuracy: 0.8728
# Epoch 69/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8816
# Epoch 70/100
# 164/164 - 0s - loss: 0.2751 - accuracy: 0.8802
# Epoch 71/100
# 164/164 - 0s - loss: 0.2705 - accuracy: 0.8825
# Epoch 72/100
# 164/164 - 0s - loss: 0.2696 - accuracy: 0.8819
# Epoch 73/100
# 164/164 - 0s - loss: 0.2689 - accuracy: 0.8898
# Epoch 74/100
# 164/164 - 0s - loss: 0.2715 - accuracy: 0.8800
# Epoch 75/100
# 164/164 - 0s - loss: 0.2773 - accuracy: 0.8808
# Epoch 76/100
# 164/164 - 0s - loss: 0.2675 - accuracy: 0.8865
# Epoch 77/100
# 164/164 - 0s - loss: 0.2701 - accuracy: 0.8825
# Epoch 78/100
# 164/164 - 0s - loss: 0.2692 - accuracy: 0.8861
# Epoch 79/100
# 164/164 - 0s - loss: 0.2679 - accuracy: 0.8867
# Epoch 80/100
# 164/164 - 0s - loss: 0.2728 - accuracy: 0.8840
# Epoch 81/100
# 164/164 - 0s - loss: 0.2651 - accuracy: 0.8865
# Epoch 82/100
# 164/164 - 0s - loss: 0.2683 - accuracy: 0.8886
# Epoch 83/100
# 164/164 - 0s - loss: 0.2763 - accuracy: 0.8802
# Epoch 84/100
# 164/164 - 0s - loss: 0.2727 - accuracy: 0.8802
# Epoch 85/100
# 164/164 - 0s - loss: 0.2708 - accuracy: 0.8827
# Epoch 86/100
# 164/164 - 0s - loss: 0.2665 - accuracy: 0.8859
# Epoch 87/100
# 164/164 - 0s - loss: 0.2666 - accuracy: 0.8875
# Epoch 88/100
# 164/164 - 0s - loss: 0.2655 - accuracy: 0.8856
# Epoch 89/100
# 164/164 - 0s - loss: 0.2699 - accuracy: 0.8861
# Epoch 90/100
# 164/164 - 0s - loss: 0.2697 - accuracy: 0.8829
# Epoch 91/100
# 164/164 - 0s - loss: 0.2702 - accuracy: 0.8837
# Epoch 92/100
# 164/164 - 0s - loss: 0.2711 - accuracy: 0.8879
# Epoch 93/100
# 164/164 - 0s - loss: 0.2631 - accuracy: 0.8915
# Epoch 94/100
# 164/164 - 0s - loss: 0.2676 - accuracy: 0.8873
# Epoch 95/100
# 164/164 - 0s - loss: 0.2661 - accuracy: 0.8905
# Epoch 96/100
# 164/164 - 0s - loss: 0.2676 - accuracy: 0.8861
# Epoch 97/100
# 164/164 - 0s - loss: 0.2673 - accuracy: 0.8865
# Epoch 98/100
# 164/164 - 0s - loss: 0.2653 - accuracy: 0.8894
# Epoch 99/100
# 164/164 - 0s - loss: 0.2656 - accuracy: 0.8892
# Epoch 100/100
# 164/164 - 0s - loss: 0.2680 - accuracy: 0.8873

# %%
# Scoring the tuned data
tuned_deep_model_loss, tuned_deep_model_accuracy = tuned_deep_model.evaluate(tuned_X_test_scaled, y_test_catagorical, verbose=2)
print(f"Normal Neural Network - Loss: {tuned_deep_model_loss}, Accuracy: {tuned_deep_model_accuracy}")
# Out:
# 55/55 - 0s - loss: 0.2717 - accuracy: 0.8924
# Normal Neural Network - Loss: 0.2716762125492096, Accuracy: 0.8924484848976135

# %%
# Compare the diffent models

print(f'deep_model accuracy: {deep_model_accuracy}')
print(f'deep_model2 accuracy: {deep_model2_accuracy}')
print(f'tuned_deep_model accuracy: {tuned_deep_model_accuracy}')

model_list = ['deep_model', 'deep_model2', 'tuned_deep_model']
accuracy_list = [deep_model_accuracy ,deep_model2_accuracy, tuned_deep_model_accuracy]

summary_df = pd.DataFrame({'Model Name': model_list, 'Model Accuracy': accuracy_list})
summary_df
# Out:
# deep_model accuracy: 0.8918764591217041
# deep_model2 accuracy: 0.8884439468383789
# tuned_deep_model accuracy: 0.8924484848976135
#          Model Name  Model Accuracy
# 0        deep_model        0.891876
# 1       deep_model2        0.888444
# 2  tuned_deep_model        0.892448

# %%
# choosing model with highest accuracy
best_model = summary_df[summary_df['Model Accuracy'] == summary_df['Model Accuracy'].max()]
best_model
# Out:
#          Model Name  Model Accuracy
# 2  tuned_deep_model        0.892448

# %%
# Saving that model

best_model_name = best_model['Model Name']
best_model_name
# Out:
# 2    tuned_deep_model
# Name: Model Name, dtype: object

# %%
# Saving the model
# deep_model2.save('Models/Neural Net/NeuralNet_Model.h5')
